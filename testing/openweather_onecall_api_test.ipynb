# %% [markdown]
# # OpenWeather One Call API Testing

# %% [markdown]
# ----------

# %% [markdown]
# This notebook's purpose is to test the [One Call API 3.0](https://openweathermap.org/api/one-call-3) from Open Weather API since in the previous notebook I had an issue with the authorization in terms of the free plan needing a subscription.
#
# So here will be the test and general look at what is returned!

# %%
# import statements

import requests
import os
from datetime import datetime
import time
from dotenv import load_dotenv, find_dotenv

# %%
# import local environmental variables (so API Keys are hidden from github repo)

load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
API_KEY = os.getenv('BLINKMETRICS_OPENWEATHER_API_KEY')

# %% [markdown]
# Getting the lat and lon values of Beirut

# %%
city_name = 'Beirut'
country_code = 'LB'
limit = 2

geo_code_url = f'http://api.openweathermap.org/geo/1.0/direct?q={city_name},{country_code}&limit={limit}&appid={API_KEY}'

# %%
# calling the api and seeing the status code (if the call worked or not)

geo_response = requests.get(geo_code_url)
geo_response.status_code
# Out:
# 200

# %%
# getting the result

geo_result = geo_response.json()
geo_result
# Out:
# [{'name': 'Beirut',
#   'local_names': {'fy': 'Beirût',
#    'pl': 'Bejrut',
#    'tt': 'Бәйрут',
#    'ja': 'ベイルート',
#    'ar': 'بيروت',
#    'hu': 'Bejrút',
#    'de': 'Beirut',
#    'zh': '貝魯特',
#    'nl': 'Beiroet',
#    'bs': 'Bejrut',
#    'eo': 'Bejruto',
#    'tg': 'Бейрут',
#    'vo': 'Bäyrut',
#    'ta': 'பெய்ரூத்',
#    'ur': 'بیروت',
#    'mr': 'बैरूत',
#    'da': 'Beirut',
#    'af': 'Beiroet',
#    'he': 'ביירות',
#    'pt': 'Beirute',
#    'hy': 'Պէյրութ',
#    'es': 'Beirut',
#    'mk': 'Бејрут',
#    'th': 'เบรุต',
#    'ga': 'Béiriút',
#    'hr': 'Bejrut',
#    'sh': 'Bejrut',
#    'cs': 'Bejrút',
#    'ru': 'Бейрут',
#    'be': 'Бейрут',
#    'br': 'Beirout',
#    'my': 'ဘေရွတ်မြို့',
#    'sv': 'Beirut',
#    'en': 'Beirut',
#    'az': 'Beyrut',
#    'ug': 'بېيرۇت',
#    'sr': 'Бејрут',
#    'ko': '베이루트',
#    'sq': 'Bejrut',
#    'la': 'Berytus',
#    'ka': 'ბეირუთი',
#    'ml': 'ബെയ്റൂത്ത്',
#    'it': 'Beirut',
#    'fr': 'Beyrouth',
#    'oc': 'Beirot',
#    'ky': 'Бейрут',
#    'bn': 'বৈরুত',
#    'feature_name': 'Beirut',
#    'mn': 'Бейрут',
#    'kn': 'ಬೈರುತ್',
#    'ht': 'Bewout',
#    'bo': 'པེ་རུ་ཐེ།',
#    'ascii': 'Beirut',
#    'os': 'Бейрут',
#    'ku': 'Bêrût',
#    'fi': 'Beirut',
#    'am': 'ቤይሩት',
#    'fa': 'بیروت',
#    'lt': 'Beirutas',
#    'uk': 'Бейрут',
#    'sl': 'Bejrut',
#    'lv': 'Beirūta',
#    'is': 'Beirút',
#    'kk': 'Бейрут',
#    'sk': 'Bejrút',
#    'eu': 'Beirut',
#    'tr': 'Beyrut',
#    'yi': 'ביירוט',
#    'bg': 'Бейрут',
#    'et': 'Beirut',
#    'el': 'Βηρυτός',
#    'hi': 'बेयरूत'},
#   'lat': 33.8959203,
#   'lon': 35.47843,
#   'country': 'LB',
#   'state': 'Beirut Governorate'}]

# %%
# getting the lat and lon values:

lat = geo_result[0]['lat']
lon = geo_result[0]['lon']

print((lat,lon))
# Out:
# (33.8959203, 35.47843)

# %% [markdown]
# Now to the One Call API (again :D)

# %%
lat = lat
lon = lon
units = 'metric'

oc_url = f'https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&units={units}&appid={API_KEY}'

# %%
# calling the api and seeing the status code (if the call worked or not)

oc_response = requests.get(oc_url)
oc_response.status_code
# Out:
# 200

# %%
oc_response.json()
# Out:
# {'lat': 33.8959,
#  'lon': 35.4784,
#  'timezone': 'Asia/Beirut',
#  'timezone_offset': 10800,
#  'current': {'dt': 1729088561,
#   'sunrise': 1729050228,
#   'sunset': 1729090983,
#   'temp': 24.85,
#   'feels_like': 25.24,
#   'pressure': 1013,
#   'humidity': 71,
#   'dew_point': 19.23,
#   'uvi': 0.4,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 1.14,
#   'wind_deg': 261,
#   'wind_gust': 0.88,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1729088580, 'precipitation': 0},
#   {'dt': 1729088640, 'precipitation': 0},
#   {'dt': 1729088700, 'precipitation': 0},
#   {'dt': 1729088760, 'precipitation': 0},
#   {'dt': 1729088820, 'precipitation': 0},
#   {'dt': 1729088880, 'precipitation': 0},
#   {'dt': 1729088940, 'precipitation': 0},
#   {'dt': 1729089000, 'precipitation': 0},
#   {'dt': 1729089060, 'precipitation': 0},
#   {'dt': 1729089120, 'precipitation': 0},
#   {'dt': 1729089180, 'precipitation': 0},
#   {'dt': 1729089240, 'precipitation': 0},
#   {'dt': 1729089300, 'precipitation': 0},
#   {'dt': 1729089360, 'precipitation': 0},
#   {'dt': 1729089420, 'precipitation': 0},
#   {'dt': 1729089480, 'precipitation': 0},
#   {'dt': 1729089540, 'precipitation': 0},
#   {'dt': 1729089600, 'precipitation': 0},
#   {'dt': 1729089660, 'precipitation': 0},
#   {'dt': 1729089720, 'precipitation': 0},
#   {'dt': 1729089780, 'precipitation': 0},
#   {'dt': 1729089840, 'precipitation': 0},
#   {'dt': 1729089900, 'precipitation': 0},
#   {'dt': 1729089960, 'precipitation': 0},
#   {'dt': 1729090020, 'precipitation': 0},
#   {'dt': 1729090080, 'precipitation': 0},
#   {'dt': 1729090140, 'precipitation': 0},
#   {'dt': 1729090200, 'precipitation': 0},
#   {'dt': 1729090260, 'precipitation': 0},
#   {'dt': 1729090320, 'precipitation': 0},
#   {'dt': 1729090380, 'precipitation': 0},
#   {'dt': 1729090440, 'precipitation': 0},
#   {'dt': 1729090500, 'precipitation': 0},
#   {'dt': 1729090560, 'precipitation': 0},
#   {'dt': 1729090620, 'precipitation': 0},
#   {'dt': 1729090680, 'precipitation': 0},
#   {'dt': 1729090740, 'precipitation': 0},
#   {'dt': 1729090800, 'precipitation': 0},
#   {'dt': 1729090860, 'precipitation': 0},
#   {'dt': 1729090920, 'precipitation': 0},
#   {'dt': 1729090980, 'precipitation': 0},
#   {'dt': 1729091040, 'precipitation': 0},
#   {'dt': 1729091100, 'precipitation': 0},
#   {'dt': 1729091160, 'precipitation': 0},
#   {'dt': 1729091220, 'precipitation': 0},
#   {'dt': 1729091280, 'precipitation': 0},
#   {'dt': 1729091340, 'precipitation': 0},
#   {'dt': 1729091400, 'precipitation': 0},
#   {'dt': 1729091460, 'precipitation': 0},
#   {'dt': 1729091520, 'precipitation': 0},
#   {'dt': 1729091580, 'precipitation': 0},
#   {'dt': 1729091640, 'precipitation': 0},
#   {'dt': 1729091700, 'precipitation': 0},
#   {'dt': 1729091760, 'precipitation': 0},
#   {'dt': 1729091820, 'precipitation': 0},
#   {'dt': 1729091880, 'precipitation': 0},
#   {'dt': 1729091940, 'precipitation': 0},
#   {'dt': 1729092000, 'precipitation': 0},
#   {'dt': 1729092060, 'precipitation': 0},
#   {'dt': 1729092120, 'precipitation': 0}],
#  'hourly': [{'dt': 1729087200,
#    'temp': 24.85,
#    'feels_like': 25.24,
#    'pressure': 1013,
#    'humidity': 71,
#    'dew_point': 19.23,
#    'uvi': 0.4,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.14,
#    'wind_deg': 261,
#    'wind_gust': 0.88,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.09},
#   {'dt': 1729090800,
#    'temp': 24.83,
#    'feels_like': 25.22,
#    'pressure': 1013,
#    'humidity': 71,
#    'dew_point': 19.21,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.53,
#    'wind_deg': 262,
#    'wind_gust': 1.05,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1729094400,
#    'temp': 24.75,
#    'feels_like': 25.16,
#    'pressure': 1013,
#    'humidity': 72,
#    'dew_point': 19.36,
#    'uvi': 0,
#    'clouds': 92,
#    'visibility': 10000,
#    'wind_speed': 1.47,
#    'wind_deg': 242,
#    'wind_gust': 1.05,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729098000,
#    'temp': 24.64,
#    'feels_like': 25.04,
#    'pressure': 1013,
#    'humidity': 72,
#    'dew_point': 19.26,
#    'uvi': 0,
#    'clouds': 81,
#    'visibility': 10000,
#    'wind_speed': 1.94,
#    'wind_deg': 242,
#    'wind_gust': 1.54,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729101600,
#    'temp': 24.47,
#    'feels_like': 24.88,
#    'pressure': 1013,
#    'humidity': 73,
#    'dew_point': 19.32,
#    'uvi': 0,
#    'clouds': 65,
#    'visibility': 10000,
#    'wind_speed': 2.68,
#    'wind_deg': 242,
#    'wind_gust': 2.35,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729105200,
#    'temp': 24.17,
#    'feels_like': 24.55,
#    'pressure': 1014,
#    'humidity': 73,
#    'dew_point': 19.1,
#    'uvi': 0,
#    'clouds': 12,
#    'visibility': 10000,
#    'wind_speed': 3.02,
#    'wind_deg': 247,
#    'wind_gust': 2.62,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1729108800,
#    'temp': 24.09,
#    'feels_like': 24.43,
#    'pressure': 1014,
#    'humidity': 72,
#    'dew_point': 18.73,
#    'uvi': 0,
#    'clouds': 35,
#    'visibility': 10000,
#    'wind_speed': 2.82,
#    'wind_deg': 235,
#    'wind_gust': 2.6,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1729112400,
#    'temp': 24.04,
#    'feels_like': 24.35,
#    'pressure': 1014,
#    'humidity': 71,
#    'dew_point': 18.5,
#    'uvi': 0,
#    'clouds': 52,
#    'visibility': 10000,
#    'wind_speed': 3.01,
#    'wind_deg': 220,
#    'wind_gust': 2.99,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729116000,
#    'temp': 23.98,
#    'feels_like': 24.26,
#    'pressure': 1014,
#    'humidity': 70,
#    'dew_point': 18.36,
#    'uvi': 0,
#    'clouds': 60,
#    'visibility': 10000,
#    'wind_speed': 3.51,
#    'wind_deg': 222,
#    'wind_gust': 3.42,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729119600,
#    'temp': 23.92,
#    'feels_like': 24.17,
#    'pressure': 1013,
#    'humidity': 69,
#    'dew_point': 18.06,
#    'uvi': 0,
#    'clouds': 66,
#    'visibility': 10000,
#    'wind_speed': 3.46,
#    'wind_deg': 220,
#    'wind_gust': 3.44,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729123200,
#    'temp': 23.95,
#    'feels_like': 24.18,
#    'pressure': 1013,
#    'humidity': 68,
#    'dew_point': 17.69,
#    'uvi': 0,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 3.5,
#    'wind_deg': 221,
#    'wind_gust': 3.36,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729126800,
#    'temp': 23.9,
#    'feels_like': 24.1,
#    'pressure': 1013,
#    'humidity': 67,
#    'dew_point': 17.5,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 3.81,
#    'wind_deg': 205,
#    'wind_gust': 3.76,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729130400,
#    'temp': 23.86,
#    'feels_like': 24.05,
#    'pressure': 1012,
#    'humidity': 67,
#    'dew_point': 17.6,
#    'uvi': 0,
#    'clouds': 88,
#    'visibility': 10000,
#    'wind_speed': 4.43,
#    'wind_deg': 215,
#    'wind_gust': 4.2,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729134000,
#    'temp': 23.44,
#    'feels_like': 23.64,
#    'pressure': 1013,
#    'humidity': 69,
#    'dew_point': 17.65,
#    'uvi': 0,
#    'clouds': 55,
#    'visibility': 10000,
#    'wind_speed': 5.03,
#    'wind_deg': 216,
#    'wind_gust': 4.79,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1729137600,
#    'temp': 23.32,
#    'feels_like': 23.54,
#    'pressure': 1013,
#    'humidity': 70,
#    'dew_point': 17.75,
#    'uvi': 0,
#    'clouds': 41,
#    'visibility': 10000,
#    'wind_speed': 5.45,
#    'wind_deg': 220,
#    'wind_gust': 5.3,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1729141200,
#    'temp': 23.41,
#    'feels_like': 23.63,
#    'pressure': 1014,
#    'humidity': 70,
#    'dew_point': 17.63,
#    'uvi': 0.26,
#    'clouds': 36,
#    'visibility': 10000,
#    'wind_speed': 5.48,
#    'wind_deg': 209,
#    'wind_gust': 5.38,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1729144800,
#    'temp': 23.68,
#    'feels_like': 23.85,
#    'pressure': 1014,
#    'humidity': 67,
#    'dew_point': 17.34,
#    'uvi': 1.05,
#    'clouds': 33,
#    'visibility': 10000,
#    'wind_speed': 5.56,
#    'wind_deg': 203,
#    'wind_gust': 5.48,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1729148400,
#    'temp': 24.03,
#    'feels_like': 24.19,
#    'pressure': 1014,
#    'humidity': 65,
#    'dew_point': 17.12,
#    'uvi': 2.34,
#    'clouds': 3,
#    'visibility': 10000,
#    'wind_speed': 5.87,
#    'wind_deg': 209,
#    'wind_gust': 5.79,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729152000,
#    'temp': 24.4,
#    'feels_like': 24.54,
#    'pressure': 1014,
#    'humidity': 63,
#    'dew_point': 16.99,
#    'uvi': 3.81,
#    'clouds': 2,
#    'visibility': 10000,
#    'wind_speed': 5.84,
#    'wind_deg': 218,
#    'wind_gust': 5.52,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729155600,
#    'temp': 24.48,
#    'feels_like': 24.63,
#    'pressure': 1014,
#    'humidity': 63,
#    'dew_point': 16.92,
#    'uvi': 4.83,
#    'clouds': 2,
#    'visibility': 10000,
#    'wind_speed': 4.91,
#    'wind_deg': 230,
#    'wind_gust': 4.27,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729159200,
#    'temp': 24.35,
#    'feels_like': 24.49,
#    'pressure': 1013,
#    'humidity': 63,
#    'dew_point': 17,
#    'uvi': 4.74,
#    'clouds': 2,
#    'visibility': 10000,
#    'wind_speed': 4.01,
#    'wind_deg': 229,
#    'wind_gust': 3.29,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729162800,
#    'temp': 24.38,
#    'feels_like': 24.54,
#    'pressure': 1012,
#    'humidity': 64,
#    'dew_point': 17.07,
#    'uvi': 3.61,
#    'clouds': 3,
#    'visibility': 10000,
#    'wind_speed': 3.43,
#    'wind_deg': 229,
#    'wind_gust': 2.72,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729166400,
#    'temp': 24.36,
#    'feels_like': 24.55,
#    'pressure': 1012,
#    'humidity': 65,
#    'dew_point': 17.32,
#    'uvi': 2.37,
#    'clouds': 3,
#    'visibility': 10000,
#    'wind_speed': 2.99,
#    'wind_deg': 238,
#    'wind_gust': 2.34,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729170000,
#    'temp': 24.24,
#    'feels_like': 24.44,
#    'pressure': 1012,
#    'humidity': 66,
#    'dew_point': 17.52,
#    'uvi': 1.35,
#    'clouds': 8,
#    'visibility': 10000,
#    'wind_speed': 2.4,
#    'wind_deg': 254,
#    'wind_gust': 1.92,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729173600,
#    'temp': 24.12,
#    'feels_like': 24.34,
#    'pressure': 1011,
#    'humidity': 67,
#    'dew_point': 17.68,
#    'uvi': 0.44,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 1.85,
#    'wind_deg': 245,
#    'wind_gust': 1.43,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729177200,
#    'temp': 23.95,
#    'feels_like': 24.18,
#    'pressure': 1012,
#    'humidity': 68,
#    'dew_point': 17.89,
#    'uvi': 0,
#    'clouds': 2,
#    'visibility': 10000,
#    'wind_speed': 1.51,
#    'wind_deg': 225,
#    'wind_gust': 1.12,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729180800,
#    'temp': 23.95,
#    'feels_like': 24.2,
#    'pressure': 1012,
#    'humidity': 69,
#    'dew_point': 17.94,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.17,
#    'wind_deg': 215,
#    'wind_gust': 0.71,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0.13},
#   {'dt': 1729184400,
#    'temp': 24,
#    'feels_like': 24.28,
#    'pressure': 1012,
#    'humidity': 70,
#    'dew_point': 18.15,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 1.09,
#    'wind_deg': 250,
#    'wind_gust': 1,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0.28},
#   {'dt': 1729188000,
#    'temp': 23.78,
#    'feels_like': 24.09,
#    'pressure': 1012,
#    'humidity': 72,
#    'dew_point': 18.4,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 0.83,
#    'wind_deg': 262,
#    'wind_gust': 0.87,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.38,
#    'rain': {'1h': 0.16}},
#   {'dt': 1729191600,
#    'temp': 23.58,
#    'feels_like': 23.9,
#    'pressure': 1012,
#    'humidity': 73,
#    'dew_point': 18.5,
#    'uvi': 0,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 0.63,
#    'wind_deg': 309,
#    'wind_gust': 0.89,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.7,
#    'rain': {'1h': 0.11}},
#   {'dt': 1729195200,
#    'temp': 23.79,
#    'feels_like': 24.1,
#    'pressure': 1012,
#    'humidity': 72,
#    'dew_point': 18.54,
#    'uvi': 0,
#    'clouds': 7,
#    'visibility': 10000,
#    'wind_speed': 1.45,
#    'wind_deg': 346,
#    'wind_gust': 1.63,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.78,
#    'rain': {'1h': 0.29}},
#   {'dt': 1729198800,
#    'temp': 23.69,
#    'feels_like': 24.02,
#    'pressure': 1012,
#    'humidity': 73,
#    'dew_point': 18.73,
#    'uvi': 0,
#    'clouds': 7,
#    'visibility': 7133,
#    'wind_speed': 2.25,
#    'wind_deg': 351,
#    'wind_gust': 2.71,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.96,
#    'rain': {'1h': 0.75}},
#   {'dt': 1729202400,
#    'temp': 23.84,
#    'feels_like': 24.16,
#    'pressure': 1012,
#    'humidity': 72,
#    'dew_point': 18.62,
#    'uvi': 0,
#    'clouds': 9,
#    'visibility': 10000,
#    'wind_speed': 2.84,
#    'wind_deg': 11,
#    'wind_gust': 3.4,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.99,
#    'rain': {'1h': 0.36}},
#   {'dt': 1729206000,
#    'temp': 24.02,
#    'feels_like': 24.23,
#    'pressure': 1012,
#    'humidity': 67,
#    'dew_point': 17.64,
#    'uvi': 0,
#    'clouds': 19,
#    'visibility': 10000,
#    'wind_speed': 3.33,
#    'wind_deg': 8,
#    'wind_gust': 3.52,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.98,
#    'rain': {'1h': 0.1}},
#   {'dt': 1729209600,
#    'temp': 23.84,
#    'feels_like': 24.03,
#    'pressure': 1011,
#    'humidity': 67,
#    'dew_point': 17.32,
#    'uvi': 0,
#    'clouds': 18,
#    'visibility': 10000,
#    'wind_speed': 2.3,
#    'wind_deg': 35,
#    'wind_gust': 2.77,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0.77},
#   {'dt': 1729213200,
#    'temp': 23.87,
#    'feels_like': 23.98,
#    'pressure': 1011,
#    'humidity': 64,
#    'dew_point': 16.8,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2,
#    'wind_deg': 10,
#    'wind_gust': 3.08,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1729216800,
#    'temp': 24.15,
#    'feels_like': 24.21,
#    'pressure': 1011,
#    'humidity': 61,
#    'dew_point': 16.34,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.11,
#    'wind_deg': 6,
#    'wind_gust': 4.54,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1729220400,
#    'temp': 24.08,
#    'feels_like': 24.11,
#    'pressure': 1011,
#    'humidity': 60,
#    'dew_point': 15.8,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 5.27,
#    'wind_deg': 10,
#    'wind_gust': 5.23,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1729224000,
#    'temp': 23.99,
#    'feels_like': 23.93,
#    'pressure': 1011,
#    'humidity': 57,
#    'dew_point': 15.08,
#    'uvi': 0,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 5.69,
#    'wind_deg': 9,
#    'wind_gust': 5.57,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729227600,
#    'temp': 24.08,
#    'feels_like': 23.95,
#    'pressure': 1012,
#    'humidity': 54,
#    'dew_point': 14.26,
#    'uvi': 0.25,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 6.19,
#    'wind_deg': 10,
#    'wind_gust': 6.02,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729231200,
#    'temp': 24.14,
#    'feels_like': 23.92,
#    'pressure': 1012,
#    'humidity': 50,
#    'dew_point': 13.22,
#    'uvi': 1.02,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 6.08,
#    'wind_deg': 6,
#    'wind_gust': 5.84,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729234800,
#    'temp': 24.2,
#    'feels_like': 23.9,
#    'pressure': 1013,
#    'humidity': 47,
#    'dew_point': 12.37,
#    'uvi': 2.37,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 5.52,
#    'wind_deg': 360,
#    'wind_gust': 5.31,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729238400,
#    'temp': 24.3,
#    'feels_like': 24.01,
#    'pressure': 1013,
#    'humidity': 47,
#    'dew_point': 12.27,
#    'uvi': 3.89,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 5.49,
#    'wind_deg': 356,
#    'wind_gust': 5.09,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729242000,
#    'temp': 24.2,
#    'feels_like': 23.9,
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 12.41,
#    'uvi': 4.96,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 5.71,
#    'wind_deg': 354,
#    'wind_gust': 5.04,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729245600,
#    'temp': 24.16,
#    'feels_like': 23.88,
#    'pressure': 1012,
#    'humidity': 48,
#    'dew_point': 12.41,
#    'uvi': 5.17,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 5.58,
#    'wind_deg': 353,
#    'wind_gust': 5.03,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729249200,
#    'temp': 24.06,
#    'feels_like': 23.75,
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 12.27,
#    'uvi': 4.35,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 5.73,
#    'wind_deg': 357,
#    'wind_gust': 5.23,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729252800,
#    'temp': 23.98,
#    'feels_like': 23.69,
#    'pressure': 1012,
#    'humidity': 48,
#    'dew_point': 12.24,
#    'uvi': 2.92,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 6.17,
#    'wind_deg': 359,
#    'wind_gust': 5.83,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1729256400,
#    'temp': 23.84,
#    'feels_like': 23.53,
#    'pressure': 1012,
#    'humidity': 48,
#    'dew_point': 12.23,
#    'uvi': 1.45,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 6.31,
#    'wind_deg': 3,
#    'wind_gust': 6.04,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0}],
#  'daily': [{'dt': 1729069200,
#    'sunrise': 1729050228,
#    'sunset': 1729090983,
#    'moonrise': 1729088640,
#    'moonset': 1729044840,
#    'moon_phase': 0.46,
#    'summary': 'Expect a day of partly cloudy with clear spells',
#    'temp': {'day': 25.21,
#     'min': 24.09,
#     'max': 25.21,
#     'night': 24.09,
#     'eve': 24.83,
#     'morn': 24.37},
#    'feels_like': {'day': 25.64, 'night': 24.43, 'eve': 25.22, 'morn': 24.85},
#    'pressure': 1015,
#    'humidity': 71,
#    'dew_point': 19.7,
#    'wind_speed': 3.02,
#    'wind_deg': 247,
#    'wind_gust': 2.62,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 61,
#    'pop': 0.29,
#    'uvi': 5.07},
#   {'dt': 1729155600,
#    'sunrise': 1729136677,
#    'sunset': 1729177310,
#    'moonrise': 1729176960,
#    'moonset': 1729135560,
#    'moon_phase': 0.5,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 24.48,
#     'min': 23.32,
#     'max': 24.48,
#     'night': 23.79,
#     'eve': 23.95,
#     'morn': 23.44},
#    'feels_like': {'day': 24.63, 'night': 24.1, 'eve': 24.18, 'morn': 23.64},
#    'pressure': 1014,
#    'humidity': 63,
#    'dew_point': 16.92,
#    'wind_speed': 5.87,
#    'wind_deg': 209,
#    'wind_gust': 5.79,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 2,
#    'pop': 0.78,
#    'rain': 0.56,
#    'uvi': 4.83},
#   {'dt': 1729242000,
#    'sunrise': 1729223125,
#    'sunset': 1729263638,
#    'moonrise': 1729265520,
#    'moonset': 1729226520,
#    'moon_phase': 0.54,
#    'summary': 'Expect a day of partly cloudy with rain',
#    'temp': {'day': 24.2,
#     'min': 23.25,
#     'max': 24.3,
#     'night': 23.26,
#     'eve': 23.54,
#     'morn': 24.08},
#    'feels_like': {'day': 23.9, 'night': 22.89, 'eve': 23.2, 'morn': 24.11},
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 12.41,
#    'wind_speed': 6.36,
#    'wind_deg': 6,
#    'wind_gust': 6.57,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 0,
#    'pop': 0.99,
#    'rain': 1.21,
#    'uvi': 5.17},
#   {'dt': 1729328400,
#    'sunrise': 1729309574,
#    'sunset': 1729349967,
#    'moonrise': 1729354380,
#    'moonset': 1729317420,
#    'moon_phase': 0.57,
#    'summary': 'There will be partly cloudy until morning, then clearing',
#    'temp': {'day': 23.45,
#     'min': 22.47,
#     'max': 23.61,
#     'night': 22.67,
#     'eve': 23.4,
#     'morn': 22.55},
#    'feels_like': {'day': 22.92, 'night': 22.32, 'eve': 23.02, 'morn': 22.04},
#    'pressure': 1016,
#    'humidity': 41,
#    'dew_point': 9.59,
#    'wind_speed': 8.6,
#    'wind_deg': 16,
#    'wind_gust': 9.41,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 5.13},
#   {'dt': 1729414800,
#    'sunrise': 1729396024,
#    'sunset': 1729436297,
#    'moonrise': 1729443720,
#    'moonset': 1729408320,
#    'moon_phase': 0.61,
#    'summary': 'Expect a day of partly cloudy with clear spells',
#    'temp': {'day': 22.59,
#     'min': 21.8,
#     'max': 23.51,
#     'night': 22.74,
#     'eve': 23.11,
#     'morn': 21.8},
#    'feels_like': {'day': 22, 'night': 22.19, 'eve': 22.55, 'morn': 21.18},
#    'pressure': 1018,
#    'humidity': 42,
#    'dew_point': 9.03,
#    'wind_speed': 8.11,
#    'wind_deg': 11,
#    'wind_gust': 8.79,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 5.08},
#   {'dt': 1729501200,
#    'sunrise': 1729482474,
#    'sunset': 1729522628,
#    'moonrise': 1729533480,
#    'moonset': 1729498980,
#    'moon_phase': 0.65,
#    'summary': 'Expect a day of partly cloudy with clear spells',
#    'temp': {'day': 22.95,
#     'min': 22.08,
#     'max': 23.54,
#     'night': 23.11,
#     'eve': 23.34,
#     'morn': 22.08},
#    'feels_like': {'day': 22.11, 'night': 22.55, 'eve': 22.72, 'morn': 21.39},
#    'pressure': 1017,
#    'humidity': 31,
#    'dew_point': 5,
#    'wind_speed': 6.05,
#    'wind_deg': 14,
#    'wind_gust': 6.38,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 3,
#    'pop': 0,
#    'uvi': 6},
#   {'dt': 1729587600,
#    'sunrise': 1729568925,
#    'sunset': 1729608960,
#    'moonrise': 1729623540,
#    'moonset': 1729589100,
#    'moon_phase': 0.68,
#    'summary': 'There will be clear sky today',
#    'temp': {'day': 23.28,
#     'min': 21.99,
#     'max': 23.35,
#     'night': 22.85,
#     'eve': 22.95,
#     'morn': 21.99},
#    'feels_like': {'day': 22.66, 'night': 22.31, 'eve': 22.27, 'morn': 21.24},
#    'pressure': 1017,
#    'humidity': 38,
#    'dew_point': 8.38,
#    'wind_speed': 6.98,
#    'wind_deg': 16,
#    'wind_gust': 7.26,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 6},
#   {'dt': 1729674000,
#    'sunrise': 1729655375,
#    'sunset': 1729695292,
#    'moonrise': 1729713780,
#    'moonset': 1729678620,
#    'moon_phase': 0.72,
#    'summary': 'The day will start with partly cloudy through the late morning hours, transitioning to clearing',
#    'temp': {'day': 23.19,
#     'min': 21.66,
#     'max': 23.42,
#     'night': 22.36,
#     'eve': 22.86,
#     'morn': 21.66},
#    'feels_like': {'day': 22.56, 'night': 21.93, 'eve': 22.43, 'morn': 20.82},
#    'pressure': 1017,
#    'humidity': 38,
#    'dew_point': 8.04,
#    'wind_speed': 7.03,
#    'wind_deg': 6,
#    'wind_gust': 7.02,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 0,
#    'pop': 0,
#    'uvi': 6}]}

# %% [markdown]
# Now to see if we can access some historical data of the weather in beirut!

# %%
lat = lat
lon = lon
date = int(time.mktime(datetime.now().timetuple()))

hist_url = f'https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={date}&appid={API_KEY}'

# %%
hist_response = requests.get(hist_url)
hist_response.status_code
# Out:
# 200

# %%
hist_response.json()
# Out:
# {'lat': 33.8959,
#  'lon': 35.4784,
#  'timezone': 'Asia/Beirut',
#  'timezone_offset': 10800,
#  'data': [{'dt': 1729089166,
#    'sunrise': 1729050228,
#    'sunset': 1729090983,
#    'temp': 298,
#    'feels_like': 298.45,
#    'pressure': 1013,
#    'humidity': 73,
#    'dew_point': 292.83,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 1.55,
#    'wind_deg': 260,
#    'wind_gust': 1.21,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}]}]}

# %% [markdown]
# since the historical data one only retrieves for one day only I will most probably not use it given the limited time that I have, however this definitely can be improved in the future and utilized to see how the weather changed over time in a certain city!
