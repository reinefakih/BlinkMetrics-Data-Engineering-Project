# %% [markdown]
# # Transformations Test

# %% [markdown]
# --------

# %% [markdown]
# The purpose of this notebook is to look at the loaded data and see how to transform to gain some insights from it!

# %% [markdown]
# ## **1. Imports + SQLalchemy Connections:**

# %% [markdown]
# ### The Imports:

# %%
# import statments:

import pandas as pd
import sqlalchemy as sa
import os
from dotenv import load_dotenv, find_dotenv
import requests

# %%
# getting the local variables that we will need

load_dotenv(find_dotenv(), override=True)

PASSWORD = os.getenv('DB_PASS')
API_KEY = os.getenv('BLINKMETRICS_OPENWEATHER_API_KEY')

# %% [markdown]
# ### Building the Connection:

# %% [markdown]
# to be able to access data from MySQL, we will use SQLAlchemy to build a connection:

# %%
# making the connection url to builg a sqlalchemy engine with it

connection_url = f"mysql+pymysql://root:{PASSWORD}@localhost:3306/blinkmetrics_project_stage"
db_engine = sa.create_engine(connection_url)

# %%
# making sure that the connection is established and successful

try:
    with db_engine.connect() as connection:
        print("Connection to MySQL database successful!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Connection to MySQL database successful!

# %% [markdown]
# ## **2. Transforming the Data:**

# %% [markdown]
# First things first, we will get all the data we have in the database.
#
# This can be done using pandas read_sql

# %%
# getting the data from the database

df = pd.read_sql("SELECT * FROM onecall", db_engine)
df
# Out:
#         lat      lon                                              daily  \
# 0   38.8950 -77.0365  [{"dt": 1729180800, "pop": 0, "uvi": 3.46, "te...
# 1   31.9516  35.9240  [{"dt": 1729155600, "pop": 0, "uvi": 5.84, "te...
# 2  -25.7459  28.1879  [{"dt": 1729155600, "pop": 0, "uvi": 11.06, "t...
# 3   45.4209 -75.6901  [{"dt": 1729180800, "pop": 0, "uvi": 2.94, "te...
# 4  -15.7934 -47.8823  [{"dt": 1729173600, "pop": 1, "uvi": 12.84, "r...
# 5   50.4500  30.5241  [{"dt": 1729155600, "pop": 0.2, "uvi": 1.84, "...
# 6   48.8589   2.3200  [{"dt": 1729162800, "pop": 1, "uvi": 0.69, "ra...
# 7   55.7504  37.6175  [{"dt": 1729155600, "pop": 0, "uvi": 1.11, "te...
# 8   41.8933  12.4829  [{"dt": 1729159200, "pop": 1, "uvi": 2.12, "ra...
# 9   33.3062  44.3872  [{"dt": 1729152000, "pop": 0, "uvi": 4.97, "te...
# 10  33.8959  35.4784  [{"dt": 1729155600, "pop": 0.84, "uvi": 4.97, ...
# 11  35.6893  51.3896  [{"dt": 1729150200, "pop": 0, "uvi": 5.39, "te...
# 12  52.5170  13.3889  [{"dt": 1729159200, "pop": 0, "uvi": 1.66, "te...
# 13  51.5073  -0.1276  [{"dt": 1729162800, "pop": 1, "uvi": 1.59, "ra...
# 14  24.4538  54.3774  [{"dt": 1729152000, "pop": 0, "uvi": 8.03, "te...
# 15  24.6389  46.7160  [{"dt": 1729152000, "pop": 0, "uvi": 7.88, "te...
# 16   4.1780  73.5107  [{"dt": 1729144800, "pop": 0, "uvi": 12.31, "t...
#
#                                                alerts  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   [{"end": 1729436400, "tags": ["Rain"], "event"...
# 5                                                None
# 6   [{"end": 1729202400, "tags": ["Rain", "Flood"]...
# 7   [{"end": 1729231200, "tags": ["Fog"], "event":...
# 8   [{"end": 1729209540, "tags": ["Rain"], "event"...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
#
#                                                hourly  \
# 0   [{"dt": 1729180800, "pop": 0, "uvi": 2.98, "te...
# 1   [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 2   [{"dt": 1729180800, "pop": 0, "uvi": 0.15, "te...
# 3   [{"dt": 1729180800, "pop": 0, "uvi": 2.62, "te...
# 4   [{"dt": 1729180800, "pop": 1, "uvi": 11.09, "r...
# 5   [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 6   [{"dt": 1729180800, "pop": 1, "uvi": 0.17, "ra...
# 7   [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 8   [{"dt": 1729180800, "pop": 0.8, "uvi": 0.01, "...
# 9   [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 10  [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 11  [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 12  [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 13  [{"dt": 1729180800, "pop": 0, "uvi": 0.21, "te...
# 14  [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 15  [{"dt": 1729180800, "pop": 0, "uvi": 0, "temp"...
# 16  [{"dt": 1729184400, "pop": 0, "uvi": 0, "temp"...
#
#                                               current  \
# 0   {"dt": 1729183416, "uvi": 3.46, "temp": 13.33,...
# 1   {"dt": 1729183622, "uvi": 0, "temp": 21.56, "c...
# 2   {"dt": 1729183711, "uvi": 0, "temp": 24.05, "c...
# 3   {"dt": 1729183796, "uvi": 2.94, "temp": 11.61,...
# 4   {"dt": 1729183843, "uvi": 5.32, "rain": {"1h":...
# 5   {"dt": 1729183890, "uvi": 0, "temp": 7.41, "cl...
# 6   {"dt": 1729183932, "uvi": 0, "rain": {"1h": 0....
# 7   {"dt": 1729183972, "uvi": 0, "temp": 7.44, "cl...
# 8   {"dt": 1729184013, "uvi": 0, "temp": 22.15, "c...
# 9   {"dt": 1729184055, "uvi": 0, "temp": 33.97, "c...
# 10  {"dt": 1729184095, "uvi": 0, "temp": 25.61, "c...
# 11  {"dt": 1729184136, "uvi": 0, "temp": 22.73, "c...
# 12  {"dt": 1729184177, "uvi": 0, "temp": 14.36, "c...
# 13  {"dt": 1729184218, "uvi": 0, "temp": 16.87, "c...
# 14  {"dt": 1729184259, "uvi": 0, "temp": 32.05, "c...
# 15  {"dt": 1729184300, "uvi": 0, "temp": 29.77, "c...
# 16  {"dt": 1729186144, "uvi": 0, "temp": 28.99, "c...
#
#                                              minutely             timezone  \
# 0   [{"dt": 1729183440, "precipitation": 0}, {"dt"...     America/New_York
# 1                                                None           Asia/Amman
# 2                                                None  Africa/Johannesburg
# 3   [{"dt": 1729183800, "precipitation": 0}, {"dt"...      America/Toronto
# 4   [{"dt": 1729183860, "precipitation": 5.7888}, ...    America/Sao_Paulo
# 5   [{"dt": 1729183920, "precipitation": 0}, {"dt"...          Europe/Kyiv
# 6   [{"dt": 1729183980, "precipitation": 0.8186}, ...         Europe/Paris
# 7   [{"dt": 1729183980, "precipitation": 0}, {"dt"...        Europe/Moscow
# 8   [{"dt": 1729184040, "precipitation": 0}, {"dt"...          Europe/Rome
# 9                                                None         Asia/Baghdad
# 10  [{"dt": 1729184100, "precipitation": 0}, {"dt"...          Asia/Beirut
# 11                                               None          Asia/Tehran
# 12  [{"dt": 1729184220, "precipitation": 0}, {"dt"...        Europe/Berlin
# 13  [{"dt": 1729184220, "precipitation": 0}, {"dt"...        Europe/London
# 14                                               None           Asia/Dubai
# 15                                               None          Asia/Riyadh
# 16  [{"dt": 1729186200, "precipitation": 0}, {"dt"...      Indian/Maldives
#
#     timezone_offset                       _airbyte_raw_id  \
# 0          -14400.0  fb44536b-3f46-4873-a537-c30e8fa4fbf9
# 1           10800.0  c7e618ab-e55c-4f34-aa06-f9abab2215bf
# 2            7200.0  4db5fe74-ee25-4253-980f-1ce3c094d8a1
# 3          -14400.0  481ba731-d01c-4eca-b6f2-71779cdf66da
# 4          -10800.0  affe7391-c458-4f3b-a477-0dcde749f795
# 5           10800.0  49014f6b-6e16-4960-94e0-67ec1efbb9e8
# 6            7200.0  4d625721-f738-4e53-b85f-5c2ccfe36cac
# 7           10800.0  a0c96b61-48a8-441f-8725-3d722adadf15
# 8            7200.0  72070460-5f75-4b08-b9cd-dcf5c8d16719
# 9           10800.0  3b7bad00-1e53-485e-b797-a3350261477c
# 10          10800.0  365329d9-ed32-451f-aef2-dfd6e563a0c9
# 11          12600.0  d9b449f9-24a7-44de-abd9-6cd280a5f138
# 12           7200.0  45889c41-a0a3-4fad-b1b9-70fd5d3dae7d
# 13           3600.0  36ee3c58-2616-4f5b-8981-17184e9bd9c0
# 14          14400.0  60038ab9-89f1-4fb9-bae0-e04d8d646572
# 15          10800.0  a95e4e7b-4281-467e-a154-5c0b192b123f
# 16          18000.0  6067eef6-8127-4fad-8f29-0ed5e0c70543
#
#      _airbyte_extracted_at    _airbyte_meta
# 0  2024-10-17 16:43:35.440  {"changes": []}
# 1  2024-10-17 16:47:01.388  {"changes": []}
# 2  2024-10-17 16:48:30.015  {"changes": []}
# 3  2024-10-17 16:49:55.288  {"changes": []}
# 4  2024-10-17 16:50:42.447  {"changes": []}
# 5  2024-10-17 16:51:28.764  {"changes": []}
# 6  2024-10-17 16:52:10.978  {"changes": []}
# 7  2024-10-17 16:52:50.646  {"changes": []}
# 8  2024-10-17 16:53:32.556  {"changes": []}
# 9  2024-10-17 16:54:14.468  {"changes": []}
# 10 2024-10-17 16:54:54.488  {"changes": []}
# 11 2024-10-17 16:55:35.498  {"changes": []}
# 12 2024-10-17 16:56:16.304  {"changes": []}
# 13 2024-10-17 16:56:57.317  {"changes": []}
# 14 2024-10-17 16:57:38.013  {"changes": []}
# 15 2024-10-17 16:58:18.593  {"changes": []}
# 16 2024-10-17 17:29:57.592  {"changes": []}

# %% [markdown]
# ### Data Samples:

# %% [markdown]
# We have alot of columns that are dictionaries or lists that will need parsing and cleaning, so let us look at a sample row of them:

# %%
daily_sample = eval(df['daily'][0])
daily_sample
# Out:
# [{'dt': 1729180800,
#   'pop': 0,
#   'uvi': 3.46,
#   'temp': {'day': 13.36,
#    'eve': 14.94,
#    'max': 15.68,
#    'min': 6.49,
#    'morn': 6.5,
#    'night': 10.77},
#   'clouds': 19,
#   'sunset': 1729203996,
#   'moonset': 1729164420,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'sunrise': 1729163991,
#   'weather': [{'id': 801,
#     'icon': '02d',
#     'main': 'Clouds',
#     'description': 'few clouds'}],
#   'humidity': 49,
#   'moonrise': 1729204140,
#   'pressure': 1025,
#   'wind_deg': 348,
#   'dew_point': 2.88,
#   'wind_gust': 10.6,
#   'feels_like': {'day': 12.03, 'eve': 13.4, 'morn': 3.75, 'night': 9.31},
#   'moon_phase': 0.5,
#   'wind_speed': 4.94},
#  {'dt': 1729267200,
#   'pop': 0,
#   'uvi': 3.89,
#   'temp': {'day': 17.47,
#    'eve': 17.75,
#    'max': 20.91,
#    'min': 8.86,
#    'morn': 9.09,
#    'night': 13.47},
#   'clouds': 0,
#   'sunset': 1729290312,
#   'moonset': 1729255560,
#   'summary': 'There will be clear sky today',
#   'sunrise': 1729250452,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 26,
#   'moonrise': 1729292520,
#   'pressure': 1032,
#   'wind_deg': 335,
#   'dew_point': -2.31,
#   'wind_gust': 10.97,
#   'feels_like': {'day': 15.95, 'eve': 16.34, 'morn': 7.27, 'night': 11.94},
#   'moon_phase': 0.55,
#   'wind_speed': 3.53},
#  {'dt': 1729353600,
#   'pop': 0,
#   'uvi': 4,
#   'temp': {'day': 19.37,
#    'eve': 19.12,
#    'max': 22.2,
#    'min': 10.34,
#    'morn': 10.66,
#    'night': 14.53},
#   'clouds': 0,
#   'sunset': 1729376629,
#   'moonset': 1729346760,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'sunrise': 1729336913,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 29,
#   'moonrise': 1729381320,
#   'pressure': 1034,
#   'wind_deg': 354,
#   'dew_point': 0.97,
#   'wind_gust': 2.59,
#   'feels_like': {'day': 18.12, 'eve': 18, 'morn': 9.22, 'night': 13.29},
#   'moon_phase': 0.59,
#   'wind_speed': 1.67},
#  {'dt': 1729440000,
#   'pop': 0,
#   'uvi': 4.01,
#   'temp': {'day': 20.81,
#    'eve': 22.81,
#    'max': 23.15,
#    'min': 11.62,
#    'morn': 11.94,
#    'night': 15.92},
#   'clouds': 9,
#   'sunset': 1729462947,
#   'moonset': 1729437780,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'sunrise': 1729423375,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 36,
#   'moonrise': 1729470600,
#   'pressure': 1028,
#   'wind_deg': 311,
#   'dew_point': 5.07,
#   'wind_gust': 2.97,
#   'feels_like': {'day': 19.89, 'eve': 21.93, 'morn': 10.65, 'night': 14.74},
#   'moon_phase': 0.62,
#   'wind_speed': 2.07},
#  {'dt': 1729526400,
#   'pop': 0,
#   'uvi': 5,
#   'temp': {'day': 20.34,
#    'eve': 24.54,
#    'max': 24.91,
#    'min': 12.88,
#    'morn': 13.21,
#    'night': 18.14},
#   'clouds': 0,
#   'sunset': 1729549265,
#   'moonset': 1729528320,
#   'summary': 'There will be clear sky today',
#   'sunrise': 1729509838,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 37,
#   'moonrise': 1729560420,
#   'pressure': 1027,
#   'wind_deg': 322,
#   'dew_point': 5.13,
#   'wind_gust': 3.64,
#   'feels_like': {'day': 19.4, 'eve': 23.86, 'morn': 12.1, 'night': 17.34},
#   'moon_phase': 0.66,
#   'wind_speed': 2.04},
#  {'dt': 1729612800,
#   'pop': 0,
#   'uvi': 5,
#   'temp': {'day': 22.55,
#    'eve': 25.86,
#    'max': 26.53,
#    'min': 15.66,
#    'morn': 15.92,
#    'night': 18.14},
#   'clouds': 0,
#   'sunset': 1729635586,
#   'moonset': 1729618260,
#   'summary': 'There will be clear sky today',
#   'sunrise': 1729596300,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 41,
#   'moonrise': 1729650660,
#   'pressure': 1025,
#   'wind_deg': 188,
#   'dew_point': 8.64,
#   'wind_gust': 4.28,
#   'feels_like': {'day': 21.93, 'eve': 25.47, 'morn': 15.16, 'night': 17.52},
#   'moon_phase': 0.69,
#   'wind_speed': 1.68},
#  {'dt': 1729699200,
#   'pop': 0,
#   'uvi': 5,
#   'temp': {'day': 19.71,
#    'eve': 24.04,
#    'max': 24.24,
#    'min': 14.74,
#    'morn': 15.17,
#    'night': 17.77},
#   'clouds': 100,
#   'sunset': 1729721907,
#   'moonset': 1729707480,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'sunrise': 1729682764,
#   'weather': [{'id': 804,
#     'icon': '04d',
#     'main': 'Clouds',
#     'description': 'overcast clouds'}],
#   'humidity': 47,
#   'moonrise': 1729741080,
#   'pressure': 1019,
#   'wind_deg': 217,
#   'dew_point': 8.04,
#   'wind_gust': 5.25,
#   'feels_like': {'day': 18.96, 'eve': 23.44, 'morn': 14.47, 'night': 17.14},
#   'moon_phase': 0.73,
#   'wind_speed': 2.27},
#  {'dt': 1729785600,
#   'pop': 0,
#   'uvi': 5,
#   'temp': {'day': 17,
#    'eve': 17.28,
#    'max': 17.28,
#    'min': 12.21,
#    'morn': 17.09,
#    'night': 12.21},
#   'clouds': 13,
#   'sunset': 1729808229,
#   'moonset': 1729796100,
#   'summary': 'You can expect partly cloudy in the morning, with clearing in the afternoon',
#   'sunrise': 1729769227,
#   'weather': [{'id': 801,
#     'icon': '02d',
#     'main': 'Clouds',
#     'description': 'few clouds'}],
#   'humidity': 56,
#   'moonrise': 0,
#   'pressure': 1017,
#   'wind_deg': 335,
#   'dew_point': 8.12,
#   'wind_gust': 10.71,
#   'feels_like': {'day': 16.22, 'eve': 16, 'morn': 16.5, 'night': 10.71},
#   'moon_phase': 0.75,
#   'wind_speed': 4.92}]

# %%
hourly_sample = eval(df['hourly'][0])
hourly_sample
# Out:
# [{'dt': 1729180800,
#   'pop': 0,
#   'uvi': 2.98,
#   'temp': 13.36,
#   'clouds': 19,
#   'weather': [{'id': 801,
#     'icon': '02d',
#     'main': 'Clouds',
#     'description': 'few clouds'}],
#   'humidity': 49,
#   'pressure': 1025,
#   'wind_deg': 330,
#   'dew_point': 2.88,
#   'wind_gust': 6.39,
#   'feels_like': 12.03,
#   'visibility': 10000,
#   'wind_speed': 4.43},
#  {'dt': 1729184400,
#   'pop': 0,
#   'uvi': 3.46,
#   'temp': 13.33,
#   'clouds': 20,
#   'weather': [{'id': 801,
#     'icon': '02d',
#     'main': 'Clouds',
#     'description': 'few clouds'}],
#   'humidity': 52,
#   'pressure': 1025,
#   'wind_deg': 339,
#   'dew_point': 3.69,
#   'wind_gust': 6.46,
#   'feels_like': 12.08,
#   'visibility': 10000,
#   'wind_speed': 4.42},
#  {'dt': 1729188000,
#   'pop': 0,
#   'uvi': 3.33,
#   'temp': 13.86,
#   'clouds': 20,
#   'weather': [{'id': 801,
#     'icon': '02d',
#     'main': 'Clouds',
#     'description': 'few clouds'}],
#   'humidity': 47,
#   'pressure': 1025,
#   'wind_deg': 339,
#   'dew_point': 2.75,
#   'wind_gust': 7.14,
#   'feels_like': 12.53,
#   'visibility': 10000,
#   'wind_speed': 4.87},
#  {'dt': 1729191600,
#   'pop': 0,
#   'uvi': 2.57,
#   'temp': 14.63,
#   'clouds': 12,
#   'weather': [{'id': 801,
#     'icon': '02d',
#     'main': 'Clouds',
#     'description': 'few clouds'}],
#   'humidity': 42,
#   'pressure': 1024,
#   'wind_deg': 348,
#   'dew_point': 1.87,
#   'wind_gust': 7.13,
#   'feels_like': 13.25,
#   'visibility': 10000,
#   'wind_speed': 4.94},
#  {'dt': 1729195200,
#   'pop': 0,
#   'uvi': 1.51,
#   'temp': 15.29,
#   'clouds': 8,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 38,
#   'pressure': 1024,
#   'wind_deg': 356,
#   'dew_point': 1.07,
#   'wind_gust': 6.85,
#   'feels_like': 13.87,
#   'visibility': 10000,
#   'wind_speed': 4.62},
#  {'dt': 1729198800,
#   'pop': 0,
#   'uvi': 0.62,
#   'temp': 15.68,
#   'clouds': 4,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 35,
#   'pressure': 1023,
#   'wind_deg': 358,
#   'dew_point': 0.28,
#   'wind_gust': 6.51,
#   'feels_like': 14.22,
#   'visibility': 10000,
#   'wind_speed': 4.05},
#  {'dt': 1729202400,
#   'pop': 0,
#   'uvi': 0.13,
#   'temp': 14.94,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 35,
#   'pressure': 1024,
#   'wind_deg': 354,
#   'dew_point': -0.32,
#   'wind_gust': 7.08,
#   'feels_like': 13.4,
#   'visibility': 10000,
#   'wind_speed': 3.61},
#  {'dt': 1729206000,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 13.32,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 41,
#   'pressure': 1024,
#   'wind_deg': 343,
#   'dew_point': 0.31,
#   'wind_gust': 7.46,
#   'feels_like': 11.78,
#   'visibility': 10000,
#   'wind_speed': 2.56},
#  {'dt': 1729209600,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 12.36,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 46,
#   'pressure': 1025,
#   'wind_deg': 339,
#   'dew_point': 0.87,
#   'wind_gust': 6.25,
#   'feels_like': 10.85,
#   'visibility': 10000,
#   'wind_speed': 2.41},
#  {'dt': 1729213200,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 11.77,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 49,
#   'pressure': 1025,
#   'wind_deg': 324,
#   'dew_point': 1.3,
#   'wind_gust': 7.72,
#   'feels_like': 10.28,
#   'visibility': 10000,
#   'wind_speed': 2.79},
#  {'dt': 1729216800,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 11.22,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 52,
#   'pressure': 1026,
#   'wind_deg': 332,
#   'dew_point': 1.39,
#   'wind_gust': 7.51,
#   'feels_like': 9.76,
#   'visibility': 10000,
#   'wind_speed': 2.62},
#  {'dt': 1729220400,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 10.77,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 54,
#   'pressure': 1027,
#   'wind_deg': 337,
#   'dew_point': 1.58,
#   'wind_gust': 7.13,
#   'feels_like': 9.31,
#   'visibility': 10000,
#   'wind_speed': 2.36},
#  {'dt': 1729224000,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 10.38,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 56,
#   'pressure': 1027,
#   'wind_deg': 337,
#   'dew_point': 1.77,
#   'wind_gust': 7.34,
#   'feels_like': 8.94,
#   'visibility': 10000,
#   'wind_speed': 2.46},
#  {'dt': 1729227600,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 10.09,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 58,
#   'pressure': 1027,
#   'wind_deg': 332,
#   'dew_point': 1.96,
#   'wind_gust': 8.89,
#   'feels_like': 8.67,
#   'visibility': 10000,
#   'wind_speed': 3.14},
#  {'dt': 1729231200,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 9.95,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 59,
#   'pressure': 1027,
#   'wind_deg': 335,
#   'dew_point': 2.09,
#   'wind_gust': 9.78,
#   'feels_like': 8.17,
#   'visibility': 10000,
#   'wind_speed': 3.53},
#  {'dt': 1729234800,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 9.66,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 60,
#   'pressure': 1028,
#   'wind_deg': 339,
#   'dew_point': 2.2,
#   'wind_gust': 10.17,
#   'feels_like': 7.85,
#   'visibility': 10000,
#   'wind_speed': 3.46},
#  {'dt': 1729238400,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 9.34,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 62,
#   'pressure': 1028,
#   'wind_deg': 346,
#   'dew_point': 2.33,
#   'wind_gust': 10.86,
#   'feels_like': 7.52,
#   'visibility': 10000,
#   'wind_speed': 3.34},
#  {'dt': 1729242000,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 9.21,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 62,
#   'pressure': 1028,
#   'wind_deg': 347,
#   'dew_point': 2.24,
#   'wind_gust': 10.97,
#   'feels_like': 7.34,
#   'visibility': 10000,
#   'wind_speed': 3.39},
#  {'dt': 1729245600,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 9.09,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 61,
#   'pressure': 1029,
#   'wind_deg': 347,
#   'dew_point': 1.81,
#   'wind_gust': 10.71,
#   'feels_like': 7.27,
#   'visibility': 10000,
#   'wind_speed': 3.25},
#  {'dt': 1729249200,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 8.86,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 60,
#   'pressure': 1030,
#   'wind_deg': 350,
#   'dew_point': 1.37,
#   'wind_gust': 10.4,
#   'feels_like': 7.13,
#   'visibility': 10000,
#   'wind_speed': 3.02},
#  {'dt': 1729252800,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 8.92,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 59,
#   'pressure': 1030,
#   'wind_deg': 341,
#   'dew_point': 1.19,
#   'wind_gust': 9.48,
#   'feels_like': 7.3,
#   'visibility': 10000,
#   'wind_speed': 2.86},
#  {'dt': 1729256400,
#   'pop': 0,
#   'uvi': 0.43,
#   'temp': 10.74,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 50,
#   'pressure': 1031,
#   'wind_deg': 347,
#   'dew_point': 0.53,
#   'wind_gust': 7.94,
#   'feels_like': 9.18,
#   'visibility': 10000,
#   'wind_speed': 3.45},
#  {'dt': 1729260000,
#   'pop': 0,
#   'uvi': 1.24,
#   'temp': 13.14,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 39,
#   'pressure': 1032,
#   'wind_deg': 353,
#   'dew_point': -0.6,
#   'wind_gust': 6.49,
#   'feels_like': 11.53,
#   'visibility': 10000,
#   'wind_speed': 3.5},
#  {'dt': 1729263600,
#   'pop': 0,
#   'uvi': 2.36,
#   'temp': 15.47,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 31,
#   'pressure': 1032,
#   'wind_deg': 355,
#   'dew_point': -1.73,
#   'wind_gust': 5.27,
#   'feels_like': 13.88,
#   'visibility': 10000,
#   'wind_speed': 3.26},
#  {'dt': 1729267200,
#   'pop': 0,
#   'uvi': 3.39,
#   'temp': 17.47,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 26,
#   'pressure': 1032,
#   'wind_deg': 1,
#   'dew_point': -2.31,
#   'wind_gust': 4.25,
#   'feels_like': 15.95,
#   'visibility': 10000,
#   'wind_speed': 2.77},
#  {'dt': 1729270800,
#   'pop': 0,
#   'uvi': 3.89,
#   'temp': 19.11,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 23,
#   'pressure': 1031,
#   'wind_deg': 1,
#   'dew_point': -2.69,
#   'wind_gust': 3.88,
#   'feels_like': 17.68,
#   'visibility': 10000,
#   'wind_speed': 2.53},
#  {'dt': 1729274400,
#   'pop': 0,
#   'uvi': 3.65,
#   'temp': 20.17,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 21,
#   'pressure': 1031,
#   'wind_deg': 4,
#   'dew_point': -3.32,
#   'wind_gust': 3.7,
#   'feels_like': 18.79,
#   'visibility': 10000,
#   'wind_speed': 2.41},
#  {'dt': 1729278000,
#   'pop': 0,
#   'uvi': 2.73,
#   'temp': 20.72,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 19,
#   'pressure': 1031,
#   'wind_deg': 3,
#   'dew_point': -3.78,
#   'wind_gust': 3.64,
#   'feels_like': 19.34,
#   'visibility': 10000,
#   'wind_speed': 2.45},
#  {'dt': 1729281600,
#   'pop': 0,
#   'uvi': 1.57,
#   'temp': 20.91,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 19,
#   'pressure': 1031,
#   'wind_deg': 3,
#   'dew_point': -3.81,
#   'wind_gust': 3.58,
#   'feels_like': 19.55,
#   'visibility': 10000,
#   'wind_speed': 2.48},
#  {'dt': 1729285200,
#   'pop': 0,
#   'uvi': 0.63,
#   'temp': 20.32,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 22,
#   'pressure': 1031,
#   'wind_deg': 1,
#   'dew_point': -2.5,
#   'wind_gust': 3.4,
#   'feels_like': 18.98,
#   'visibility': 10000,
#   'wind_speed': 2.26},
#  {'dt': 1729288800,
#   'pop': 0,
#   'uvi': 0.13,
#   'temp': 17.75,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 29,
#   'pressure': 1031,
#   'wind_deg': 347,
#   'dew_point': -0.78,
#   'wind_gust': 3.43,
#   'feels_like': 16.34,
#   'visibility': 10000,
#   'wind_speed': 1.79},
#  {'dt': 1729292400,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 15.74,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 34,
#   'pressure': 1032,
#   'wind_deg': 357,
#   'dew_point': -0.16,
#   'wind_gust': 3.43,
#   'feels_like': 14.26,
#   'visibility': 10000,
#   'wind_speed': 1.61},
#  {'dt': 1729296000,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 14.82,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 37,
#   'pressure': 1032,
#   'wind_deg': 9,
#   'dew_point': 0.13,
#   'wind_gust': 3.54,
#   'feels_like': 13.32,
#   'visibility': 10000,
#   'wind_speed': 1.6},
#  {'dt': 1729299600,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 14.28,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 38,
#   'pressure': 1032,
#   'wind_deg': 6,
#   'dew_point': 0.02,
#   'wind_gust': 3.39,
#   'feels_like': 12.76,
#   'visibility': 10000,
#   'wind_speed': 1.59},
#  {'dt': 1729303200,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 13.82,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 40,
#   'pressure': 1032,
#   'wind_deg': 9,
#   'dew_point': 0.18,
#   'wind_gust': 3.11,
#   'feels_like': 12.3,
#   'visibility': 10000,
#   'wind_speed': 1.54},
#  {'dt': 1729306800,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 13.47,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 41,
#   'pressure': 1033,
#   'wind_deg': 13,
#   'dew_point': 0.4,
#   'wind_gust': 2.5,
#   'feels_like': 11.94,
#   'visibility': 10000,
#   'wind_speed': 1.56},
#  {'dt': 1729310400,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 12.93,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 44,
#   'pressure': 1033,
#   'wind_deg': 2,
#   'dew_point': 0.69,
#   'wind_gust': 1.65,
#   'feels_like': 11.43,
#   'visibility': 10000,
#   'wind_speed': 1.34},
#  {'dt': 1729314000,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 12.59,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 46,
#   'pressure': 1033,
#   'wind_deg': 1,
#   'dew_point': 1.11,
#   'wind_gust': 1.79,
#   'feels_like': 11.11,
#   'visibility': 10000,
#   'wind_speed': 1.49},
#  {'dt': 1729317600,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 12.05,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 49,
#   'pressure': 1033,
#   'wind_deg': 7,
#   'dew_point': 1.4,
#   'wind_gust': 1.64,
#   'feels_like': 10.59,
#   'visibility': 10000,
#   'wind_speed': 1.29},
#  {'dt': 1729321200,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 11.53,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 51,
#   'pressure': 1034,
#   'wind_deg': 348,
#   'dew_point': 1.56,
#   'wind_gust': 1.39,
#   'feels_like': 10.07,
#   'visibility': 10000,
#   'wind_speed': 1.24},
#  {'dt': 1729324800,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 11.25,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 52,
#   'pressure': 1033,
#   'wind_deg': 360,
#   'dew_point': 1.69,
#   'wind_gust': 1.75,
#   'feels_like': 9.79,
#   'visibility': 10000,
#   'wind_speed': 1.45},
#  {'dt': 1729328400,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 10.98,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 54,
#   'pressure': 1034,
#   'wind_deg': 354,
#   'dew_point': 1.78,
#   'wind_gust': 2.3,
#   'feels_like': 9.54,
#   'visibility': 10000,
#   'wind_speed': 1.62},
#  {'dt': 1729332000,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 10.66,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 55,
#   'pressure': 1034,
#   'wind_deg': 354,
#   'dew_point': 1.83,
#   'wind_gust': 2.59,
#   'feels_like': 9.22,
#   'visibility': 10000,
#   'wind_speed': 1.67},
#  {'dt': 1729335600,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 10.34,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01n',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 56,
#   'pressure': 1034,
#   'wind_deg': 2,
#   'dew_point': 1.8,
#   'wind_gust': 2.47,
#   'feels_like': 8.89,
#   'visibility': 10000,
#   'wind_speed': 1.58},
#  {'dt': 1729339200,
#   'pop': 0,
#   'uvi': 0,
#   'temp': 10.64,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 55,
#   'pressure': 1034,
#   'wind_deg': 1,
#   'dew_point': 1.84,
#   'wind_gust': 2.16,
#   'feels_like': 9.2,
#   'visibility': 10000,
#   'wind_speed': 1.34},
#  {'dt': 1729342800,
#   'pop': 0,
#   'uvi': 0.42,
#   'temp': 12.89,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 47,
#   'pressure': 1035,
#   'wind_deg': 13,
#   'dew_point': 1.56,
#   'wind_gust': 2.19,
#   'feels_like': 11.46,
#   'visibility': 10000,
#   'wind_speed': 1.33},
#  {'dt': 1729346400,
#   'pop': 0,
#   'uvi': 1.25,
#   'temp': 15.36,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 38,
#   'pressure': 1035,
#   'wind_deg': 11,
#   'dew_point': 1.12,
#   'wind_gust': 1.86,
#   'feels_like': 13.94,
#   'visibility': 10000,
#   'wind_speed': 1.18},
#  {'dt': 1729350000,
#   'pop': 0,
#   'uvi': 2.4,
#   'temp': 17.54,
#   'clouds': 0,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 33,
#   'pressure': 1034,
#   'wind_deg': 12,
#   'dew_point': 0.92,
#   'wind_gust': 1.72,
#   'feels_like': 16.21,
#   'visibility': 10000,
#   'wind_speed': 1.15}]

# %%
current_sample = eval(df['current'][0])
current_sample
# Out:
# {'dt': 1729183416,
#  'uvi': 3.46,
#  'temp': 13.33,
#  'clouds': 20,
#  'sunset': 1729203996,
#  'sunrise': 1729163991,
#  'weather': [{'id': 801,
#    'icon': '02d',
#    'main': 'Clouds',
#    'description': 'few clouds'}],
#  'humidity': 52,
#  'pressure': 1025,
#  'wind_deg': 360,
#  'dew_point': 3.69,
#  'feels_like': 12.08,
#  'visibility': 10000,
#  'wind_speed': 6.69}

# %%
minutely_sample = eval(df['minutely'][0])
minutely_sample
# Out:
# [{'dt': 1729183440, 'precipitation': 0},
#  {'dt': 1729183500, 'precipitation': 0},
#  {'dt': 1729183560, 'precipitation': 0},
#  {'dt': 1729183620, 'precipitation': 0},
#  {'dt': 1729183680, 'precipitation': 0},
#  {'dt': 1729183740, 'precipitation': 0},
#  {'dt': 1729183800, 'precipitation': 0},
#  {'dt': 1729183860, 'precipitation': 0},
#  {'dt': 1729183920, 'precipitation': 0},
#  {'dt': 1729183980, 'precipitation': 0},
#  {'dt': 1729184040, 'precipitation': 0},
#  {'dt': 1729184100, 'precipitation': 0},
#  {'dt': 1729184160, 'precipitation': 0},
#  {'dt': 1729184220, 'precipitation': 0},
#  {'dt': 1729184280, 'precipitation': 0},
#  {'dt': 1729184340, 'precipitation': 0},
#  {'dt': 1729184400, 'precipitation': 0},
#  {'dt': 1729184460, 'precipitation': 0},
#  {'dt': 1729184520, 'precipitation': 0},
#  {'dt': 1729184580, 'precipitation': 0},
#  {'dt': 1729184640, 'precipitation': 0},
#  {'dt': 1729184700, 'precipitation': 0},
#  {'dt': 1729184760, 'precipitation': 0},
#  {'dt': 1729184820, 'precipitation': 0},
#  {'dt': 1729184880, 'precipitation': 0},
#  {'dt': 1729184940, 'precipitation': 0},
#  {'dt': 1729185000, 'precipitation': 0},
#  {'dt': 1729185060, 'precipitation': 0},
#  {'dt': 1729185120, 'precipitation': 0},
#  {'dt': 1729185180, 'precipitation': 0},
#  {'dt': 1729185240, 'precipitation': 0},
#  {'dt': 1729185300, 'precipitation': 0},
#  {'dt': 1729185360, 'precipitation': 0},
#  {'dt': 1729185420, 'precipitation': 0},
#  {'dt': 1729185480, 'precipitation': 0},
#  {'dt': 1729185540, 'precipitation': 0},
#  {'dt': 1729185600, 'precipitation': 0},
#  {'dt': 1729185660, 'precipitation': 0},
#  {'dt': 1729185720, 'precipitation': 0},
#  {'dt': 1729185780, 'precipitation': 0},
#  {'dt': 1729185840, 'precipitation': 0},
#  {'dt': 1729185900, 'precipitation': 0},
#  {'dt': 1729185960, 'precipitation': 0},
#  {'dt': 1729186020, 'precipitation': 0},
#  {'dt': 1729186080, 'precipitation': 0},
#  {'dt': 1729186140, 'precipitation': 0},
#  {'dt': 1729186200, 'precipitation': 0},
#  {'dt': 1729186260, 'precipitation': 0},
#  {'dt': 1729186320, 'precipitation': 0},
#  {'dt': 1729186380, 'precipitation': 0},
#  {'dt': 1729186440, 'precipitation': 0},
#  {'dt': 1729186500, 'precipitation': 0},
#  {'dt': 1729186560, 'precipitation': 0},
#  {'dt': 1729186620, 'precipitation': 0},
#  {'dt': 1729186680, 'precipitation': 0},
#  {'dt': 1729186740, 'precipitation': 0},
#  {'dt': 1729186800, 'precipitation': 0},
#  {'dt': 1729186860, 'precipitation': 0},
#  {'dt': 1729186920, 'precipitation': 0},
#  {'dt': 1729186980, 'precipitation': 0}]

# %% [markdown]
# we will be dealing with the daily values, as they make the most sense for analysis!, so we will ignore the rest of the columns that needs parsing and only clean out the daily values.

# %% [markdown]
# ### Getting City Names:

# %% [markdown]
# to begin with, we will transform the latitude and longitude values to their corresponding city

# %% [markdown]
# To do so, we will use the open weather reverse geocoding api!

# %%
# testing out the parameters first to see if it is working:

lat = df['lat'][10]
lon = df['lon'][10]
limit = 1

url = f"http://api.openweathermap.org/geo/1.0/reverse?lat={lat}&lon={lon}&limit={limit}&appid={API_KEY}"

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'name': 'El Hamra',
#   'local_names': {'ar': 'الحمراء',
#    'de': 'Hamra',
#    'en': 'El Hamra',
#    'fr': 'Hamra'},
#   'lat': 33.896744850000005,
#   'lon': 35.482964894984065,
#   'country': 'LB',
#   'state': 'Beirut Governorate'}]

# %%
response.json()[0]['name']
# Out:
# 'El Hamra'

# %% [markdown]
# since this is working and we got the jist of what we want to get the city name, we will make a function that we will use to get the city name for each row automatically!

# %%
# fucntion to get the city name using the open weather reverse geocoding api

def get_city_name(lat, lon):
    
    limit = 1

    url = f"http://api.openweathermap.org/geo/1.0/reverse?lat={lat}&lon={lon}&limit={limit}&appid={API_KEY}"

    response = requests.get(url)

    return {'name': response.json()[0]['name'], 'country': response.json()[0]['country']}

# %%
# applying the function to each row:

df['city'] = df.apply(lambda row: get_city_name(row['lat'], row['lon'])['name'], axis=1)

# %%
# making sure everything is working:

df['city']
# Out:
# 0       Washington
# 1            Amman
# 2         Pretoria
# 3     (Old) Ottawa
# 4     Plano Piloto
# 5             Kyiv
# 6            Paris
# 7           Moscow
# 8             Rome
# 9             Dora
# 10        El Hamra
# 11          Tehran
# 12          Berlin
# 13          London
# 14       Abu Dhabi
# 15          Riyadh
# 16            Malé
# Name: city, dtype: object

# %% [markdown]
# To take this a step further, we will also add the country code as it will help us with the analysis too!

# %%
# using the previously made function to also get the country code

df['country'] = df.apply(lambda row: get_city_name(row['lat'], row['lon'])['country'], axis=1)

# %%
# making sure it works

df['country']
# Out:
# 0     US
# 1     JO
# 2     ZA
# 3     CA
# 4     BR
# 5     UA
# 6     FR
# 7     RU
# 8     IT
# 9     IQ
# 10    LB
# 11    IR
# 12    DE
# 13    GB
# 14    AE
# 15    SA
# 16    MV
# Name: country, dtype: object

# %% [markdown]
# the names are abit different but it's okay, it wont hinder our analysis! (we can try using a different API or a library)

# %% [markdown]
# I have added both city name and country name!

# %% [markdown]
# ### Making dim_cities:

# %% [markdown]
# now we can take the distinct city names and their respective country and put them in their own df as they are a dim table

# %%
dim_cities = df[['city', 'country']] # getting the newly added city column and the country column from the df to make a new df from them
dim_cities = dim_cities.drop_duplicates() # dropping any duplicated rows

dim_cities['city_id'] = range(1, len(dim_cities)  + 1) # adding an id column

dim_cities = dim_cities[['city_id', 'city', 'country']] # organizing the columns

dim_cities # making sure everything worked
# Out:
# C:\Users\allab\AppData\Local\Temp\ipykernel_3228\2481682976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dim_cities['city_id'] = range(1, len(cities)  + 1)
#     city_id          city country
# 0         1    Washington      US
# 1         2         Amman      JO
# 2         3      Pretoria      ZA
# 3         4  (Old) Ottawa      CA
# 4         5  Plano Piloto      BR
# 5         6          Kyiv      UA
# 6         7         Paris      FR
# 7         8        Moscow      RU
# 8         9          Rome      IT
# 9        10          Dora      IQ
# 10       11      El Hamra      LB
# 11       12        Tehran      IR
# 12       13        Berlin      DE
# 13       14        London      GB
# 14       15     Abu Dhabi      AE
# 15       16        Riyadh      SA
# 16       17          Malé      MV

# %% [markdown]
# ### Fixing the Main DF:

# %% [markdown]
# and now to extract the values we want to do the analysis fro the main df:

# %%
# since we want to only work with the daily values we will select the daily column along side some other columns we can utilize:

new_df = df[['city', 'country', 'daily', '_airbyte_extracted_at']]

# %%
new_df # making sure it worked
# Out:
#             city country                                              daily  \
# 0     Washington      US  [{"dt": 1729180800, "pop": 0, "uvi": 3.46, "te...
# 1          Amman      JO  [{"dt": 1729155600, "pop": 0, "uvi": 5.84, "te...
# 2       Pretoria      ZA  [{"dt": 1729155600, "pop": 0, "uvi": 11.06, "t...
# 3   (Old) Ottawa      CA  [{"dt": 1729180800, "pop": 0, "uvi": 2.94, "te...
# 4   Plano Piloto      BR  [{"dt": 1729173600, "pop": 1, "uvi": 12.84, "r...
# 5           Kyiv      UA  [{"dt": 1729155600, "pop": 0.2, "uvi": 1.84, "...
# 6          Paris      FR  [{"dt": 1729162800, "pop": 1, "uvi": 0.69, "ra...
# 7         Moscow      RU  [{"dt": 1729155600, "pop": 0, "uvi": 1.11, "te...
# 8           Rome      IT  [{"dt": 1729159200, "pop": 1, "uvi": 2.12, "ra...
# 9           Dora      IQ  [{"dt": 1729152000, "pop": 0, "uvi": 4.97, "te...
# 10      El Hamra      LB  [{"dt": 1729155600, "pop": 0.84, "uvi": 4.97, ...
# 11        Tehran      IR  [{"dt": 1729150200, "pop": 0, "uvi": 5.39, "te...
# 12        Berlin      DE  [{"dt": 1729159200, "pop": 0, "uvi": 1.66, "te...
# 13        London      GB  [{"dt": 1729162800, "pop": 1, "uvi": 1.59, "ra...
# 14     Abu Dhabi      AE  [{"dt": 1729152000, "pop": 0, "uvi": 8.03, "te...
# 15        Riyadh      SA  [{"dt": 1729152000, "pop": 0, "uvi": 7.88, "te...
# 16          Malé      MV  [{"dt": 1729144800, "pop": 0, "uvi": 12.31, "t...
#
#      _airbyte_extracted_at
# 0  2024-10-17 16:43:35.440
# 1  2024-10-17 16:47:01.388
# 2  2024-10-17 16:48:30.015
# 3  2024-10-17 16:49:55.288
# 4  2024-10-17 16:50:42.447
# 5  2024-10-17 16:51:28.764
# 6  2024-10-17 16:52:10.978
# 7  2024-10-17 16:52:50.646
# 8  2024-10-17 16:53:32.556
# 9  2024-10-17 16:54:14.468
# 10 2024-10-17 16:54:54.488
# 11 2024-10-17 16:55:35.498
# 12 2024-10-17 16:56:16.304
# 13 2024-10-17 16:56:57.317
# 14 2024-10-17 16:57:38.013
# 15 2024-10-17 16:58:18.593
# 16 2024-10-17 17:29:57.592

# %% [markdown]
# #### The Daily Column:

# %% [markdown]
# and now to fix the daily column

# %% [markdown]
# the daily column rows consist of a list containing a number of elements

# %%
len(eval(new_df['daily'][0])) # seeing how many elements we have in the list
# Out:
# 8

# %% [markdown]
# the daily column is a list that contains 8 days

# %%
eval(new_df['daily'][0])[0] # checking a sample of the data for each day
# Out:
# {'dt': 1729180800,
#  'pop': 0,
#  'uvi': 3.46,
#  'temp': {'day': 13.36,
#   'eve': 14.94,
#   'max': 15.68,
#   'min': 6.49,
#   'morn': 6.5,
#   'night': 10.77},
#  'clouds': 19,
#  'sunset': 1729203996,
#  'moonset': 1729164420,
#  'summary': 'Expect a day of partly cloudy with clear spells',
#  'sunrise': 1729163991,
#  'weather': [{'id': 801,
#    'icon': '02d',
#    'main': 'Clouds',
#    'description': 'few clouds'}],
#  'humidity': 49,
#  'moonrise': 1729204140,
#  'pressure': 1025,
#  'wind_deg': 348,
#  'dew_point': 2.88,
#  'wind_gust': 10.6,
#  'feels_like': {'day': 12.03, 'eve': 13.4, 'morn': 3.75, 'night': 9.31},
#  'moon_phase': 0.5,
#  'wind_speed': 4.94}

# %% [markdown]
# each day is a dictionary that contains some metrics we want, so the first thing we want to do is turn each day into it's own row

# %% [markdown]
# since originally the daily column is a string, we can use eval to turn it into an iterable list!

# %%
new_df['daily'] = new_df['daily'].apply(lambda row: eval(row)) # turning the rows of the daily column from strings to list
# Out:
# C:\Users\allab\AppData\Local\Temp\ipykernel_3228\342179585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['daily'] = new_df['daily'].apply(lambda row: eval(row))

# %%
new_df['daily'][0] # checking if it worked
# Out:
# [{'dt': 1729180800,
#   'pop': 0,
#   'uvi': 3.46,
#   'temp': {'day': 13.36,
#    'eve': 14.94,
#    'max': 15.68,
#    'min': 6.49,
#    'morn': 6.5,
#    'night': 10.77},
#   'clouds': 19,
#   'sunset': 1729203996,
#   'moonset': 1729164420,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'sunrise': 1729163991,
#   'weather': [{'id': 801,
#     'icon': '02d',
#     'main': 'Clouds',
#     'description': 'few clouds'}],
#   'humidity': 49,
#   'moonrise': 1729204140,
#   'pressure': 1025,
#   'wind_deg': 348,
#   'dew_point': 2.88,
#   'wind_gust': 10.6,
#   'feels_like': {'day': 12.03, 'eve': 13.4, 'morn': 3.75, 'night': 9.31},
#   'moon_phase': 0.5,
#   'wind_speed': 4.94},
#  {'dt': 1729267200,
#   'pop': 0,
#   'uvi': 3.89,
#   'temp': {'day': 17.47,
#    'eve': 17.75,
#    'max': 20.91,
#    'min': 8.86,
#    'morn': 9.09,
#    'night': 13.47},
#   'clouds': 0,
#   'sunset': 1729290312,
#   'moonset': 1729255560,
#   'summary': 'There will be clear sky today',
#   'sunrise': 1729250452,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 26,
#   'moonrise': 1729292520,
#   'pressure': 1032,
#   'wind_deg': 335,
#   'dew_point': -2.31,
#   'wind_gust': 10.97,
#   'feels_like': {'day': 15.95, 'eve': 16.34, 'morn': 7.27, 'night': 11.94},
#   'moon_phase': 0.55,
#   'wind_speed': 3.53},
#  {'dt': 1729353600,
#   'pop': 0,
#   'uvi': 4,
#   'temp': {'day': 19.37,
#    'eve': 19.12,
#    'max': 22.2,
#    'min': 10.34,
#    'morn': 10.66,
#    'night': 14.53},
#   'clouds': 0,
#   'sunset': 1729376629,
#   'moonset': 1729346760,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'sunrise': 1729336913,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 29,
#   'moonrise': 1729381320,
#   'pressure': 1034,
#   'wind_deg': 354,
#   'dew_point': 0.97,
#   'wind_gust': 2.59,
#   'feels_like': {'day': 18.12, 'eve': 18, 'morn': 9.22, 'night': 13.29},
#   'moon_phase': 0.59,
#   'wind_speed': 1.67},
#  {'dt': 1729440000,
#   'pop': 0,
#   'uvi': 4.01,
#   'temp': {'day': 20.81,
#    'eve': 22.81,
#    'max': 23.15,
#    'min': 11.62,
#    'morn': 11.94,
#    'night': 15.92},
#   'clouds': 9,
#   'sunset': 1729462947,
#   'moonset': 1729437780,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'sunrise': 1729423375,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 36,
#   'moonrise': 1729470600,
#   'pressure': 1028,
#   'wind_deg': 311,
#   'dew_point': 5.07,
#   'wind_gust': 2.97,
#   'feels_like': {'day': 19.89, 'eve': 21.93, 'morn': 10.65, 'night': 14.74},
#   'moon_phase': 0.62,
#   'wind_speed': 2.07},
#  {'dt': 1729526400,
#   'pop': 0,
#   'uvi': 5,
#   'temp': {'day': 20.34,
#    'eve': 24.54,
#    'max': 24.91,
#    'min': 12.88,
#    'morn': 13.21,
#    'night': 18.14},
#   'clouds': 0,
#   'sunset': 1729549265,
#   'moonset': 1729528320,
#   'summary': 'There will be clear sky today',
#   'sunrise': 1729509838,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 37,
#   'moonrise': 1729560420,
#   'pressure': 1027,
#   'wind_deg': 322,
#   'dew_point': 5.13,
#   'wind_gust': 3.64,
#   'feels_like': {'day': 19.4, 'eve': 23.86, 'morn': 12.1, 'night': 17.34},
#   'moon_phase': 0.66,
#   'wind_speed': 2.04},
#  {'dt': 1729612800,
#   'pop': 0,
#   'uvi': 5,
#   'temp': {'day': 22.55,
#    'eve': 25.86,
#    'max': 26.53,
#    'min': 15.66,
#    'morn': 15.92,
#    'night': 18.14},
#   'clouds': 0,
#   'sunset': 1729635586,
#   'moonset': 1729618260,
#   'summary': 'There will be clear sky today',
#   'sunrise': 1729596300,
#   'weather': [{'id': 800,
#     'icon': '01d',
#     'main': 'Clear',
#     'description': 'clear sky'}],
#   'humidity': 41,
#   'moonrise': 1729650660,
#   'pressure': 1025,
#   'wind_deg': 188,
#   'dew_point': 8.64,
#   'wind_gust': 4.28,
#   'feels_like': {'day': 21.93, 'eve': 25.47, 'morn': 15.16, 'night': 17.52},
#   'moon_phase': 0.69,
#   'wind_speed': 1.68},
#  {'dt': 1729699200,
#   'pop': 0,
#   'uvi': 5,
#   'temp': {'day': 19.71,
#    'eve': 24.04,
#    'max': 24.24,
#    'min': 14.74,
#    'morn': 15.17,
#    'night': 17.77},
#   'clouds': 100,
#   'sunset': 1729721907,
#   'moonset': 1729707480,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'sunrise': 1729682764,
#   'weather': [{'id': 804,
#     'icon': '04d',
#     'main': 'Clouds',
#     'description': 'overcast clouds'}],
#   'humidity': 47,
#   'moonrise': 1729741080,
#   'pressure': 1019,
#   'wind_deg': 217,
#   'dew_point': 8.04,
#   'wind_gust': 5.25,
#   'feels_like': {'day': 18.96, 'eve': 23.44, 'morn': 14.47, 'night': 17.14},
#   'moon_phase': 0.73,
#   'wind_speed': 2.27},
#  {'dt': 1729785600,
#   'pop': 0,
#   'uvi': 5,
#   'temp': {'day': 17,
#    'eve': 17.28,
#    'max': 17.28,
#    'min': 12.21,
#    'morn': 17.09,
#    'night': 12.21},
#   'clouds': 13,
#   'sunset': 1729808229,
#   'moonset': 1729796100,
#   'summary': 'You can expect partly cloudy in the morning, with clearing in the afternoon',
#   'sunrise': 1729769227,
#   'weather': [{'id': 801,
#     'icon': '02d',
#     'main': 'Clouds',
#     'description': 'few clouds'}],
#   'humidity': 56,
#   'moonrise': 0,
#   'pressure': 1017,
#   'wind_deg': 335,
#   'dew_point': 8.12,
#   'wind_gust': 10.71,
#   'feels_like': {'day': 16.22, 'eve': 16, 'morn': 16.5, 'night': 10.71},
#   'moon_phase': 0.75,
#   'wind_speed': 4.92}]

# %% [markdown]
# now, we can use panda's explode to turn each list item into it's own row:

# %%
# turning each list item into it's own row:

exp_df = new_df.explode('daily', ignore_index=True)

# %%
exp_df.head() # making sure it worked
# Out:
#          city country                                              daily  \
# 0  Washington      US  {'dt': 1729180800, 'pop': 0, 'uvi': 3.46, 'tem...
# 1  Washington      US  {'dt': 1729267200, 'pop': 0, 'uvi': 3.89, 'tem...
# 2  Washington      US  {'dt': 1729353600, 'pop': 0, 'uvi': 4, 'temp':...
# 3  Washington      US  {'dt': 1729440000, 'pop': 0, 'uvi': 4.01, 'tem...
# 4  Washington      US  {'dt': 1729526400, 'pop': 0, 'uvi': 5, 'temp':...
#
#     _airbyte_extracted_at
# 0 2024-10-17 16:43:35.440
# 1 2024-10-17 16:43:35.440
# 2 2024-10-17 16:43:35.440
# 3 2024-10-17 16:43:35.440
# 4 2024-10-17 16:43:35.440

# %% [markdown]
# now let us see how out new rows in the daily column look like and what we need to do to them!

# %%
exp_df['daily'][0] # checking a row
# Out:
# {'dt': 1729180800,
#  'pop': 0,
#  'uvi': 3.46,
#  'temp': {'day': 13.36,
#   'eve': 14.94,
#   'max': 15.68,
#   'min': 6.49,
#   'morn': 6.5,
#   'night': 10.77},
#  'clouds': 19,
#  'sunset': 1729203996,
#  'moonset': 1729164420,
#  'summary': 'Expect a day of partly cloudy with clear spells',
#  'sunrise': 1729163991,
#  'weather': [{'id': 801,
#    'icon': '02d',
#    'main': 'Clouds',
#    'description': 'few clouds'}],
#  'humidity': 49,
#  'moonrise': 1729204140,
#  'pressure': 1025,
#  'wind_deg': 348,
#  'dew_point': 2.88,
#  'wind_gust': 10.6,
#  'feels_like': {'day': 12.03, 'eve': 13.4, 'morn': 3.75, 'night': 9.31},
#  'moon_phase': 0.5,
#  'wind_speed': 4.94}

# %% [markdown]
# as we can see, each row is a dictionary.
#
# The goal now is to turn each key in the dictionary into it's own column :D

# %%
daily_exp = exp_df['daily'].apply(pd.Series) # making a df that contains all the keys that were turned into a column

exp_df = pd.concat([exp_df.drop(columns=['daily']), daily_exp], axis=1) # combining the main df with the newly created one while also droping the daily column

# %%
exp_df.head() # making sure it worked
# Out:
#          city country   _airbyte_extracted_at          dt  pop   uvi  \
# 0  Washington      US 2024-10-17 16:43:35.440  1729180800  0.0  3.46
# 1  Washington      US 2024-10-17 16:43:35.440  1729267200  0.0  3.89
# 2  Washington      US 2024-10-17 16:43:35.440  1729353600  0.0  4.00
# 3  Washington      US 2024-10-17 16:43:35.440  1729440000  0.0  4.01
# 4  Washington      US 2024-10-17 16:43:35.440  1729526400  0.0  5.00
#
#                                                 temp  clouds      sunset  \
# 0  {'day': 13.36, 'eve': 14.94, 'max': 15.68, 'mi...      19  1729203996
# 1  {'day': 17.47, 'eve': 17.75, 'max': 20.91, 'mi...       0  1729290312
# 2  {'day': 19.37, 'eve': 19.12, 'max': 22.2, 'min...       0  1729376629
# 3  {'day': 20.81, 'eve': 22.81, 'max': 23.15, 'mi...       9  1729462947
# 4  {'day': 20.34, 'eve': 24.54, 'max': 24.91, 'mi...       0  1729549265
#
#       moonset  ... humidity    moonrise pressure  wind_deg  dew_point  \
# 0  1729164420  ...       49  1729204140     1025       348       2.88
# 1  1729255560  ...       26  1729292520     1032       335      -2.31
# 2  1729346760  ...       29  1729381320     1034       354       0.97
# 3  1729437780  ...       36  1729470600     1028       311       5.07
# 4  1729528320  ...       37  1729560420     1027       322       5.13
#
#    wind_gust                                         feels_like  moon_phase  \
# 0      10.60  {'day': 12.03, 'eve': 13.4, 'morn': 3.75, 'nig...        0.50
# 1      10.97  {'day': 15.95, 'eve': 16.34, 'morn': 7.27, 'ni...        0.55
# 2       2.59  {'day': 18.12, 'eve': 18, 'morn': 9.22, 'night...        0.59
# 3       2.97  {'day': 19.89, 'eve': 21.93, 'morn': 10.65, 'n...        0.62
# 4       3.64  {'day': 19.4, 'eve': 23.86, 'morn': 12.1, 'nig...        0.66
#
#    wind_speed rain
# 0        4.94  NaN
# 1        3.53  NaN
# 2        1.67  NaN
# 3        2.07  NaN
# 4        2.04  NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# we can see that some of the new added columns need some extra cleaning and parsing, so let's do that too

# %% [markdown]
# now to repeat this step for temp, weather, and feels like!

# %% [markdown]
# **1. temp column:**

# %%
temp_exp = exp_df['temp'].apply(pd.Series)

temp_exp = temp_exp.add_prefix('temp_')

exp_df = pd.concat([exp_df.drop(columns=['temp']), temp_exp], axis=1)

# %% [markdown]
# **2. weather column:**

# %% [markdown]
# this column needed some more work since it was a list first, not a dict

# %%
exp_df['weather'] = exp_df['weather'].apply(lambda row: row[0])

# %%
exp_df['weather'][0]
# Out:
# {'id': 801, 'icon': '02d', 'main': 'Clouds', 'description': 'few clouds'}

# %%
weather_exp = exp_df['weather'].apply(pd.Series)

exp_df = pd.concat([exp_df.drop(columns=['weather']), weather_exp], axis=1)

# %% [markdown]
# **3. feels like column:**

# %%
feell_exp = exp_df['feels_like'].apply(pd.Series)

feell_exp = feell_exp.add_prefix('feels_like_')

exp_df = pd.concat([exp_df.drop(columns=['feels_like']), feell_exp], axis=1)

# %%
exp_df.head() # making sure everything works
# Out:
#          city country   _airbyte_extracted_at          dt  pop   uvi  clouds  \
# 0  Washington      US 2024-10-17 16:43:35.440  1729180800  0.0  3.46      19
# 1  Washington      US 2024-10-17 16:43:35.440  1729267200  0.0  3.89       0
# 2  Washington      US 2024-10-17 16:43:35.440  1729353600  0.0  4.00       0
# 3  Washington      US 2024-10-17 16:43:35.440  1729440000  0.0  4.01       9
# 4  Washington      US 2024-10-17 16:43:35.440  1729526400  0.0  5.00       0
#
#        sunset     moonset                                          summary  \
# 0  1729203996  1729164420  Expect a day of partly cloudy with clear spells
# 1  1729290312  1729255560                    There will be clear sky today
# 2  1729376629  1729346760  Expect a day of partly cloudy with clear spells
# 3  1729462947  1729437780  Expect a day of partly cloudy with clear spells
# 4  1729549265  1729528320                    There will be clear sky today
#
#    ...  temp_morn  temp_night   id  icon    main  description  feels_like_day  \
# 0  ...       6.50       10.77  801   02d  Clouds   few clouds           12.03
# 1  ...       9.09       13.47  800   01d   Clear    clear sky           15.95
# 2  ...      10.66       14.53  800   01d   Clear    clear sky           18.12
# 3  ...      11.94       15.92  800   01d   Clear    clear sky           19.89
# 4  ...      13.21       18.14  800   01d   Clear    clear sky           19.40
#
#    feels_like_eve  feels_like_morn  feels_like_night
# 0           13.40             3.75              9.31
# 1           16.34             7.27             11.94
# 2           18.00             9.22             13.29
# 3           21.93            10.65             14.74
# 4           23.86            12.10             17.34
#
# [5 rows x 34 columns]

# %% [markdown]
# #### turning the dt column from UNIX to regular datetime format:

# %% [markdown]
# the date column "dt" that indicates which day the row corresponds to is in the unix format, we will transform it so it is easier to use for analysis

# %%
# transforming the dt column from UNIX to regular datetime format:

exp_df['dt'] = pd.to_datetime(exp_df['dt'], unit='s')

# %%
exp_df['dt'] # making sure it worked
# Out:
# 0     2024-10-17 16:00:00
# 1     2024-10-18 16:00:00
# 2     2024-10-19 16:00:00
# 3     2024-10-20 16:00:00
# 4     2024-10-21 16:00:00
#               ...
# 131   2024-10-20 06:00:00
# 132   2024-10-21 06:00:00
# 133   2024-10-22 06:00:00
# 134   2024-10-23 06:00:00
# 135   2024-10-24 06:00:00
# Name: dt, Length: 136, dtype: datetime64[ns]

# %% [markdown]
# #### Cleaning up the df columns:

# %% [markdown]
# Now let us organize the columns we have so that they look closer to the warehouse table:

# %%
exp_df.columns # getting the columns so we don't miss any
# Out:
# Index(['city', 'country', '_airbyte_extracted_at', 'dt', 'pop', 'uvi',
#        'clouds', 'sunset', 'moonset', 'summary', 'sunrise', 'humidity',
#        'moonrise', 'pressure', 'wind_deg', 'dew_point', 'wind_gust',
#        'moon_phase', 'wind_speed', 'rain', 'temp_day', 'temp_eve', 'temp_max',
#        'temp_min', 'temp_morn', 'temp_night', 'id', 'icon', 'main',
#        'description', 'feels_like_day', 'feels_like_eve', 'feels_like_morn',
#        'feels_like_night'],
#       dtype='object')

# %%
# making a new df with the organized columns

cleaned_df = exp_df[['dt', 'city', 'summary', 'temp_morn', 'temp_day', 'temp_eve', 'temp_night', 'temp_min', 'temp_max', 'feels_like_morn', 'feels_like_day', 'feels_like_eve', 'feels_like_night', 'pressure', 'humidity', 'dew_point', 'wind_speed', 'wind_gust', 'clouds', 'uvi', 'pop', 'rain', 'id', '_airbyte_extracted_at']]

# %%
cleaned_df.info() # taking a look at how the columns are now
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dt                     136 non-null    datetime64[ns]
#  1   city                   136 non-null    object
#  2   summary                136 non-null    object
#  3   temp_morn              136 non-null    float64
#  4   temp_day               136 non-null    float64
#  5   temp_eve               136 non-null    float64
#  6   temp_night             136 non-null    float64
#  7   temp_min               136 non-null    float64
#  8   temp_max               136 non-null    float64
#  9   feels_like_morn        136 non-null    float64
#  10  feels_like_day         136 non-null    float64
#  11  feels_like_eve         136 non-null    float64
#  12  feels_like_night       136 non-null    float64
#  13  pressure               136 non-null    int64
#  14  humidity               136 non-null    int64
#  15  dew_point              136 non-null    float64
#  16  wind_speed             136 non-null    float64
#  17  wind_gust              136 non-null    float64
#  18  clouds                 136 non-null    int64
#  19  uvi                    136 non-null    float64
#  20  pop                    136 non-null    float64
#  21  rain                   38 non-null     float64
#  22  id                     136 non-null    int64
#  23  _airbyte_extracted_at  136 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(16), int64(4), object(2)
# memory usage: 25.6+ KB

# %%
# renaming some of the columns so they have similar naming to the ones in the warehouse

cleaned_df = cleaned_df.rename(columns={'dt': 'date', 'pop': 'precep_prob', 'id': 'weather_id', '_airbyte_extracted_at': 'extracted_at'})

# %%
cleaned_df['id'] = range(1, len(cleaned_df) + 1) # adding an id

# %%
cleaned_df.columns # making sure it worked
# Out:
# Index(['date', 'city', 'summary', 'temp_morn', 'temp_day', 'temp_eve',
#        'temp_night', 'temp_min', 'temp_max', 'feels_like_morn',
#        'feels_like_day', 'feels_like_eve', 'feels_like_night', 'pressure',
#        'humidity', 'dew_point', 'wind_speed', 'wind_gust', 'clouds', 'uvi',
#        'precep_prob', 'rain', 'weather_id', 'extracted_at', 'id'],
#       dtype='object')

# %% [markdown]
# now to clean up the dates abit since i dont want them as datetime:

# %%
# keeping the date part only:

cleaned_df['date'] = cleaned_df['date'].dt.strftime('%Y-%m-%d')
cleaned_df['extracted_at'] = cleaned_df['extracted_at'].dt.strftime('%Y-%m-%d')

# %%
# change type from string to datetime

cleaned_df['date'] = pd.to_datetime(cleaned_df['date'])
cleaned_df['extracted_at'] = pd.to_datetime(cleaned_df['extracted_at'])

# %%
cleaned_df.head() # making sure it worked
# Out:
#         date        city                                          summary  \
# 0 2024-10-17  Washington  Expect a day of partly cloudy with clear spells
# 1 2024-10-18  Washington                    There will be clear sky today
# 2 2024-10-19  Washington  Expect a day of partly cloudy with clear spells
# 3 2024-10-20  Washington  Expect a day of partly cloudy with clear spells
# 4 2024-10-21  Washington                    There will be clear sky today
#
#    temp_morn  temp_day  temp_eve  temp_night  temp_min  temp_max  \
# 0       6.50     13.36     14.94       10.77      6.49     15.68
# 1       9.09     17.47     17.75       13.47      8.86     20.91
# 2      10.66     19.37     19.12       14.53     10.34     22.20
# 3      11.94     20.81     22.81       15.92     11.62     23.15
# 4      13.21     20.34     24.54       18.14     12.88     24.91
#
#    feels_like_morn  ...  dew_point  wind_speed  wind_gust  clouds   uvi  \
# 0             3.75  ...       2.88        4.94      10.60      19  3.46
# 1             7.27  ...      -2.31        3.53      10.97       0  3.89
# 2             9.22  ...       0.97        1.67       2.59       0  4.00
# 3            10.65  ...       5.07        2.07       2.97       9  4.01
# 4            12.10  ...       5.13        2.04       3.64       0  5.00
#
#    precep_prob  rain  weather_id  extracted_at  id
# 0          0.0   NaN         801    2024-10-17   1
# 1          0.0   NaN         800    2024-10-17   2
# 2          0.0   NaN         800    2024-10-17   3
# 3          0.0   NaN         800    2024-10-17   4
# 4          0.0   NaN         800    2024-10-17   5
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Making the Weather Dim:

# %% [markdown]
# since before we made a df with just the weather details, we will utilize it to make the weather dim

# %%
dim_weather = weather_exp[['id', 'main', 'description']].drop_duplicates() # taking the df we had already dropping the dupes and adding them to a new df
dim_weather = dim_weather.rename(columns={'id': 'weather_id', 'main': 'weather'}) # renaming the columns so they are the same as in the warehouse
dim_weather = dim_weather.sort_values('weather_id', ascending=True) # sorting the rows by the weather_id

# %%
dim_weather # making sure it worked
# Out:
#     weather_id weather           description
# 17         500    Rain            light rain
# 34         501    Rain         moderate rain
# 32         502    Rain  heavy intensity rain
# 1          800   Clear             clear sky
# 0          801  Clouds            few clouds
# 28         802  Clouds      scattered clouds
# 27         803  Clouds         broken clouds
# 6          804  Clouds       overcast clouds

# %% [markdown]
# ### Finalizing the Fact table:

# %% [markdown]
# Firstly, I want to get the city id and add it to the fact table as it's a foreign key referencing the city dim then drop the city column

# %%
final_fact = cleaned_df.merge(dim_cities, on='city', how='inner') # merging the cleaned df from before with the dim cities

# %%
final_fact # making sure it worked
# Out:
#           date        city                                          summary  \
# 0   2024-10-17  Washington  Expect a day of partly cloudy with clear spells
# 1   2024-10-18  Washington                    There will be clear sky today
# 2   2024-10-19  Washington  Expect a day of partly cloudy with clear spells
# 3   2024-10-20  Washington  Expect a day of partly cloudy with clear spells
# 4   2024-10-21  Washington                    There will be clear sky today
# ..         ...         ...                                              ...
# 131 2024-10-20        Malé  Expect a day of partly cloudy with clear spells
# 132 2024-10-21        Malé                There will be partly cloudy today
# 133 2024-10-22        Malé          Expect a day of partly cloudy with rain
# 134 2024-10-23        Malé          Expect a day of partly cloudy with rain
# 135 2024-10-24        Malé          Expect a day of partly cloudy with rain
#
#      temp_morn  temp_day  temp_eve  temp_night  temp_min  temp_max  \
# 0         6.50     13.36     14.94       10.77      6.49     15.68
# 1         9.09     17.47     17.75       13.47      8.86     20.91
# 2        10.66     19.37     19.12       14.53     10.34     22.20
# 3        11.94     20.81     22.81       15.92     11.62     23.15
# 4        13.21     20.34     24.54       18.14     12.88     24.91
# ..         ...       ...       ...         ...       ...       ...
# 131      27.82     27.96     28.06       28.01     27.70     28.24
# 132      28.11     28.10     28.35       28.04     27.94     28.35
# 133      27.71     27.92     27.98       28.00     27.71     28.32
# 134      27.81     27.94     28.18       28.21     27.66     28.21
# 135      28.09     28.27     28.20       28.21     28.02     28.52
#
#      feels_like_morn  ...  wind_gust  clouds    uvi  precep_prob  rain  \
# 0               3.75  ...      10.60      19   3.46          0.0   NaN
# 1               7.27  ...      10.97       0   3.89          0.0   NaN
# 2               9.22  ...       2.59       0   4.00          0.0   NaN
# 3              10.65  ...       2.97       9   4.01          0.0   NaN
# 4              12.10  ...       3.64       0   5.00          0.0   NaN
# ..               ...  ...        ...     ...    ...          ...   ...
# 131            30.70  ...       5.62      33   7.39          0.0   NaN
# 132            30.61  ...       5.14      44  11.76          0.0   NaN
# 133            30.48  ...       5.00      51  12.00          0.2  0.12
# 134            30.68  ...       6.57      64  12.00          1.0  2.31
# 135            31.26  ...       7.50      95  12.00          1.0  1.68
#
#      weather_id  extracted_at   id  city_id  country
# 0           801    2024-10-17    1        1       US
# 1           800    2024-10-17    2        1       US
# 2           800    2024-10-17    3        1       US
# 3           800    2024-10-17    4        1       US
# 4           800    2024-10-17    5        1       US
# ..          ...           ...  ...      ...      ...
# 131         802    2024-10-17  132       17       MV
# 132         802    2024-10-17  133       17       MV
# 133         500    2024-10-17  134       17       MV
# 134         500    2024-10-17  135       17       MV
# 135         500    2024-10-17  136       17       MV
#
# [136 rows x 27 columns]

# %%
final_fact.columns # looking at the column we have to make sure to drop the unnecessary ones
# Out:
# Index(['date', 'city', 'summary', 'temp_morn', 'temp_day', 'temp_eve',
#        'temp_night', 'temp_min', 'temp_max', 'feels_like_morn',
#        'feels_like_day', 'feels_like_eve', 'feels_like_night', 'pressure',
#        'humidity', 'dew_point', 'wind_speed', 'wind_gust', 'clouds', 'uvi',
#        'precep_prob', 'rain', 'weather_id', 'extracted_at', 'id', 'city_id',
#        'country'],
#       dtype='object')

# %%
final_fact = final_fact.drop(columns=['city', 'country'], axis=0) # dropping the unnecessary columns
final_fact = final_fact[['id', 'date', 'city_id', 'summary', 'temp_morn', 'temp_day', 'temp_eve',
       'temp_night', 'temp_min', 'temp_max', 'feels_like_morn',
       'feels_like_day', 'feels_like_eve', 'feels_like_night', 'pressure',
       'precep_prob', 'rain', 'weather_id', 'extracted_at']] # organizing the columns the way we want them in the warehouse schema

# %%
final_fact.info() # making sure it all worked
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                136 non-null    int64
#  1   date              136 non-null    datetime64[ns]
#  2   city_id           136 non-null    int64
#  3   summary           136 non-null    object
#  4   temp_morn         136 non-null    float64
#  5   temp_day          136 non-null    float64
#  6   temp_eve          136 non-null    float64
#  7   temp_night        136 non-null    float64
#  8   temp_min          136 non-null    float64
#  9   temp_max          136 non-null    float64
#  10  feels_like_morn   136 non-null    float64
#  11  feels_like_day    136 non-null    float64
#  12  feels_like_eve    136 non-null    float64
#  13  feels_like_night  136 non-null    float64
#  14  pressure          136 non-null    int64
#  15  precep_prob       136 non-null    float64
#  16  rain              38 non-null     float64
#  17  weather_id        136 non-null    int64
#  18  extracted_at      136 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# memory usage: 20.3+ KB

# %% [markdown]
# and we are done with the transformations :D, all this can be now turned into a python script :D
